# %% [markdown]
# # Exemplo de extração de dados de páginas web
#
# # https://www.vivareal.com.br/venda/?pagina=5
#
# Este notebook extrai os dados de todos os [imóveis a venda no site VivaReal](https://www.vivareal.com.br/venda/) e escreve os dados extraidos num banco de dados (SQLIte).
#
# ![cartao-vivareal.png](cartao-vivareal.png)
#
# Na última verificação, o site tinha 277 páginas de imóveis, 36 imóveis por página. Se deixá-lo rodar integralmente, teremos no final quase 10000 imóveis.
#
# Notebook escrito por Avi Alkalay <<DataScientist@digitalhouse.com>>

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import sqlite3

# %%
# 2 opções de URL
urlBrasil = "https://www.vivareal.com.br/venda/?pagina={npagina}"
urlPinheiros = "https://www.vivareal.com.br/venda/sp/sao-paulo/zona-oeste/pinheiros/apartamento_residencial/?pagina={npagina}"

# Vamos trabalhar com esta:
url=urlBrasil

# Para enganar o site, permutaremos entre 2 opções de assinaturas de browser.
# Peguei de https://developers.whatismybrowser.com/
userAgents=[
    "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/74.0.3729.157 Safari/537.36",
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/12.1.1 Safari/605.1.15"
]

dbfile = 'VivaReal.db'
tabela = 'venda'

# %% [markdown]
# ## Análise inicial de cada elemento da página
#
# Este trecho serve para testarmos a extração de cada elemento desejado, seja nome do imóvel, preço etc. Quando compreendido, movemos o trecho de código finalizado para o bloco mais adiante no notebook, em que o scrapping é feito em lote.

# %% [markdown]
# ### Passo 1: Traz o HTML do site
#
# Use o `requests` para fazer uma operação HTTP GET e obter o HTML da página.

# %%
doc = requests.get(url.format(npagina=1), headers={"User-agent": userAgents[1]})

# %% [markdown]
# Vamos verificar o que o webserver retornou olhando só os 700 primeiros bytes (variavel `olhadinha`).

# %%
olhadinha=700
print(str(doc.content[:olhadinha]) + '…')
# Out:
# b' <!DOCTYPE html> <html lang="pt-BR"> <head>  <script type="bf948744663da505b3bdeb50-text/javascript"> (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n      (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n    m=s.getElementsByTagName(o)[0];a.src=g;m.parentNode.insertBefore(a,m)\n  })(window,document,\'script\',\'https://www.google-analytics.com/analytics.js\',\'ga\');\n  ga(\'create\', \'UA-126375-31\', \'auto\'); </script> <script src="https://www.googleoptimize.com/optimize.js?id=GTM-PVK4X33" type="bf948744663da505b3bdeb50-text/javascript"></script>  <script type="bf948744663da505b3bdeb50-text/javascript"> var pageCategory = \'RESULT PAGE\';\n\n  co'…

# %%
doc.status_code
# Out:
# 200

# %% [markdown]
# ### Passo 2: Analiza o texto HTML
#
# A biblioteca `BeautifulSoup` tem a capacidade de analizar o HTML entregue pelo site (que não é nada mais que texto corrido, como vimos), e convertê-lo em DOM (document object model). O DOM é o mesmo documento HTML só que todas as tags e sua hierarquia foram identificadas ao ponto de podermos fazer buscas por tags e attributos de seus tags.

# %%
analizador = BeautifulSoup(doc.content, 'html.parser')

# %% [markdown]
# A variável `analizador` agora contém o DOM do texto retornado pelo web server. Então agora usamos ela para buscar tags específicas.
#
# Usamos o _inspector_ do browser para entender a estrutura do documento que o HTMLeiro da VivaReal concebeu. Descobrimos que os imóveis estão publicados assim:
#
# ```html
# <div id="12345">
#     <div class="js-card-selector">
#         ...mais tags sobre o imóvel...
#     </div>
# </div>
#
# <div id="54321">
#     <div class="js-card-selector">
#         ...mais tags sobre o imóvel...
#     </div>
# </div>
# ```
#
# Cada imóvel está contido dentro de seu respectivo `<div id="....">`, mas não temos nada específico e genérico nesta tag para selecioná-la. Já a tag imediatamente interior, `<div class="js-card-selector">`, é idêntica para cada imóvel e contém a classe `js-card-selector`, o que a torna uma ótima candidata para ser selecionada.
#
# Então abaixo criaremos uma lista chamada `imoveis` que contém todos os trechos DOM que respeitam o nosso filtro: `<div>`s com classe `js-card-selector`.

# %%
analizador
# Out:
#  <!DOCTYPE html>
#  <html lang="pt-BR"> <head> <script type="bf948744663da505b3bdeb50-text/javascript"> (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#       (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-126375-31', 'auto'); </script> <script src="https://www.googleoptimize.com/optimize.js?id=GTM-PVK4X33" type="bf948744663da505b3bdeb50-text/javascript"></script> <script type="bf948744663da505b3bdeb50-text/javascript"> var pageCategory = 'RESULT PAGE';
#
#   const clickstreamTracker = function (rawData) {
#     const clickstreamTrackerEndpoint = 'https://tracking.vivareal.com/events/v2';
#     const data = JSON.stringify(rawData);
#
#     if (navigator.sendBeacon) {
#       navigator.sendBeacon(clickstreamTrackerEndpoint, data);
#     } else {
#       const ajax = new XMLHttpRequest();
#       ajax.open('POST', clickstreamTrackerEndpoint, true);
#       ajax.send(data);
#     }
#   };
#
#   (function () {
#     const getCookie = function(name) {
#       const value = `; ${document.cookie}`;
#       const parts = value.split(`; ${name}=`);
#
#       if (parts.length == 2) return parts.pop().split(';').shift();
#       return '';
#     }
#
#     const cuid = function() {
#       return ([1e7]+-1e3+-4e3+-8e3+-1e11).replace(/[018]/g, function(c) {
#         return (c ^ crypto.getRandomValues(new Uint8Array(1))[0] & 15 >> c / 4)
#           .toString(16);
#       });
#     }
#
#     const loadAnonymousId = function() {
#      const userAnonymousKey = 'new_vivareal_user_id';
#      loadAnonymousGenerationDate();
#
#      let id = getCookie(userAnonymousKey);
#
#      if (!id) {
#        id = cuid();
#        document.cookie = [userAnonymousKey, id].join('=') + '; expires= Mon, 1 Jan 2099 00:00:00 UTC; path=/ ';
#      }
#
#      return id;
#    }
#
#     const loadAnonymousGenerationDate = function() {
#      const userAnonymousKey = 'new_vivareal_user_id_generation_date';
#      let date = getCookie(userAnonymousKey);
#
#      if (!date) {
#        date = new Date();
#        document.cookie = [userAnonymousKey, date].join('=') + '; expires= Mon, 1 Jan 2099 00:00:00 UTC; path=/ ';
#      }
#
#      return date;
#    }
#
#     const loadSessionId = function() {
#       const userSessionKey = 'V_USER_SESSION';
#
#       let id = sessionStorage.getItem(userSessionKey);
#
#       if (!id) {
#         id = cuid();
#         sessionStorage.setItem(userSessionKey, id);
#       }
#
#       return id;
#     }
#
#     window.addEventListener('message', ({ origin, data: { GZUID } }) => {
#       if (origin.includes('https://gzuis.grupozap.com') && GZUID) {
#         localStorage.setItem('GZUID', GZUID)
#       }
#     })
#
#     const loadGzuid = function() {
#       return localStorage.getItem('GZUID') || null;
#     }
#
#     window.dataLayerName = 'dataLayer';
#
#     var EVENTS_MAP = {
#       'CONDOMINIUM DETAIL PAGE': undefined,
#       'DISCOVER': undefined,
#       'HOME': 'homeRendered',
#       'PREVIEW': 'listingRendered',
#       'DEFAULTER ADVERTISER LISTING DETAIL PAGE': 'listingRendered',
#       'DEVELOPMENT DETAIL PAGE': 'listingRendered',
#       'LISTING DETAIL PAGE': 'listingRendered',
#       'DEFAULTER ADVERTISER INACTIVE LISTING DETAIL PAGE': 'listingRendered',
#       'INACTIVE LISTING DETAIL PAGE': 'listingRendered',
#       'PUBLISHER PAGE': 'rankingRendered',
#       'RESULT PAGE': 'rankingRendered',
#       'MINHA CASA MINHA VIDA': undefined,
#       'ACCOUNT PAGE': undefined,
#     };
#
#     window[window.dataLayerName] = [{
#       anonymous_id: loadAnonymousId(),
#       anonymous_id_generation_date: loadAnonymousGenerationDate(),
#       device_sent_timestamp: Date.now(),
#       experiment_id: '',
#       page_category: pageCategory,
#       platform: (window.outerWidth < 640) ? 'MOBILE' : 'DESKTOP',
#       session_id: loadSessionId(),
#       user_id: getCookie('vrSessionToken'),
#       variation_name: '',
#       metomic_event: EVENTS_MAP[pageCategory],
#       gzuid: loadGzuid(),
#     }];
#
#     navigator.geolocation.getCurrentPosition(function (position) {
#       window[window.dataLayerName].push({
#         connection_latitude: position.coords.latitude,
#         connection_longitude: position.coords.longitude,
#         accuracy_lat_long: position.coords.accuracy,
#       })
#     });
#   })(); </script> <noscript> <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-NP5VKCD" style="display:none;visibility:hidden" width="0"> </iframe> </noscript> <script type="bf948744663da505b3bdeb50-text/javascript"> (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#       '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window, document, 'script', window.dataLayerName, 'GTM-NP5VKCD'); </script> <link href="//cdn1.vivareal.com" rel="dns-prefetch"/> <link href="//resizedimgs.vivareal.com" rel="dns-prefetch"/> <link href="//tracking.vivareal.com" rel="dns-prefetch"/> <link href="//api.vivareal.com" rel="dns-prefetch"/> <link href="//www.googletagmanager.com" rel="dns-prefetch"/> <link href="//www.googleoptimize.com" rel="dns-prefetch"/> <link href="//www.googletagservices.com" rel="dns-prefetch"/> <link href="//www.googleadservices.com" rel="dns-prefetch"/> <link href="//www.google-analytics.com" rel="dns-prefetch"/> <link href="https://googleads.g.doubleclick.net" rel="dns-prefetch"/> <link href="//static.criteo.net" rel="dns-prefetch"/> <link href="//widget.criteo.com" rel="dns-prefetch"/> <link href="//dis.us.criteo.com" rel="dns-prefetch"/> <link href="//bam.nr-data.net" rel="dns-prefetch"/> <link href="//script.crazyegg.com" rel="dns-prefetch"/> <link href="https://analytics.twitter.com" rel="dns-prefetch"/> <link href="//platform.twitter.com" rel="dns-prefetch"/> <style type="text/css"> .mcmv-buttons{margin-top:16px;width:100%}.mcmv-buttons,.mcmv-buttons__prev{display:-webkit-box;display:-ms-flexbox;display:flex}.mcmv-buttons__prev{font-size:13px;line-height:21px;font-weight:600;background-color:#fff;color:#1190cd;cursor:pointer;outline:none;text-transform:lowercase}.mcmv-buttons__prev:before{background-color:#0a5a80;content:"";display:inline-block;height:100%;-webkit-mask:url(https://cdn1.vivareal.com/p/15026-153a25f35/v/static/app/svg/styleguide/icons/ic-chevron-up-gray.svg) no-repeat center;mask:url(https://cdn1.vivareal.com/p/15026-153a25f35/v/static/app/svg/styleguide/icons/ic-chevron-up-gray.svg) no-repeat center;min-height:20px;width:20px;margin-top:1px;-webkit-transform:rotate(-90deg);transform:rotate(-90deg)}@media screen and (max-width:719px){.mcmv-buttons__prev.finish{margin-top:24px}}.mcmv-buttons__next{font-size:16px;font-weight:600;height:48px;line-height:48px;vertical-align:middle;-webkit-appearance:none;-moz-appearance:none;appearance:none;border-radius:4px;cursor:pointer;display:inline-block;text-align:center;text-decoration:none;background:#ee6500;border:0;color:#fff;padding:0 32px}.mcmv-buttons__next:focus{outline:0}.mcmv-buttons__next[disabled]{cursor:not-allowed;opacity:.5}.mcmv-buttons__next:not([disabled]):hover{background:#ff7109}.mcmv-buttons__next:active{background:#da5c00}.mcmv-buttons__next.finish{width:100%}.mcmv-buttons.wrap{-ms-flex-wrap:wrap;flex-wrap:wrap}@media screen and (max-width:719px){.mcmv-buttons{-webkit-box-pack:justify;-ms-flex-pack:justify;justify-content:space-between}.mcmv-buttons.end{-webkit-box-pack:end;-ms-flex-pack:end;justify-content:flex-end}}@media screen and (min-width:720px){.mcmv-buttons{-webkit-box-pack:end;-ms-flex-pack:end;justify-content:flex-end}.mcmv-buttons__prev{left:0;position:absolute;top:0}}.vr-modal .filters__wrapper{display:block;padding:0;position:relative;overflow:visible;width:100%}.vr-modal .filters__wrapper .filters__location{position:relative}.vr-modal .filters__wrapper .filters__location .location-suggestions__container{font-size:13px;font-weight:400;line-height:21px;background:#fff;border-radius:4px;-webkit-box-shadow:0 8px 16px 0 rgba(0,0,0,.2);box-shadow:0 8px 16px 0 rgba(0,0,0,.2);display:none;overflow:auto;text-align:left;width:100%;left:0;max-height:300px;position:absolute;top:48px;z-index:5}.vr-modal .filters__wrapper .filters__location .location-suggestions__container[data-active],.vr-modal .filters__wrapper .filters__location .location-suggestions__container[data-empty]{display:block}.vr-modal .filters__wrapper .filters__location .location-suggestions__container[data-empty]{z-index:10;margin-top:0}.vr-modal .filters__wrapper .filters__location .location-suggestions__container[data-empty] span{font-size:13px;padding:12px;display:block;background:#73a4e6;border-radius:4px;text-align:center;color:#fff}.vr-modal .filters__wrapper .filters__location .loc ...
#   "@context": "https://schema.org",
#   "@type": "BreadcrumbList",
#   "itemListElement": [
#     {
#       "@type": "ListItem",
#       "position": "1",
#       "item": {
#         "@id": "/",
#         "name": "Viva Real"
#       }
#     }  ,{
#       "@type": "ListItem",
#       "position": "2",
#       "item": {
#         "@id": "",
#         "name": "Venda"
#       }
#     }  ]
# } </script> </div> <div class="results__container"> <div class="results__content"> <nav class="filters__wrapper js-filters-container"> <div class="filters-panel__container js-open-filters-mobile"> <div class="filters-panel__wrapper js-filters filters-panel__wrapper-- "> <form action="#" method="GET"> <fieldset class="filters-panel__main-filters"> <button class="filters-panel__close js-close-filters" type="button"></button> <label class="filters-panel__title">Editar filtros</label> <div class="form__field"> <label class="form__label" for="filter-location-search-input">Localização do Imóvel</label> <div class="js-location"> <div class="filters__location"> <input autocomplete="off" class="js-input" id="filter-location-search-input" placeholder="Digite uma rua, bairro ou cidade" type="text"/> <div class="js-suggestions"></div> </div> </div> </div> <div class="js-videos-virtual-tour"> <div class="form__field--select "> <label class="form__label">Imóvel com </label> <div class="videos-virtual-tour"> <div class="videos-virtual-tour__switcher-container "> <input class="js-videos-virtual-tour-check" id="filter-videos-virtual-tour" type="checkbox" value="videos-virtual-tour-value"/> </div> <label for="filter-videos-virtual-tour">Tour Virtual ou Vídeos</label> </div> </div> </div> <div class="form__field--select"> <label class="form__label" for="filter-used-type">Tipo de Imóvel</label> <div class="js-unit-type"> <div class="form__select-multiple-wrapper"> <input class="select-multiple__input js-filter-used-type" disabled="disabled" id="filter-used-type" type="checkbox"/> <label class="select-multiple__static js-used-unit-type" for="filter-used-type">Mostrar todos</label> <div class="select-multiple__container"> <label class="select-multiple__subtitle js-cancel" for="filter-used-type">Tipo de imóvel</label> <div class="select-multiple__column"> <h5 class="select-multiple__title">Residencial</h5> <ul class="select-multiple__list"> <li class="select-multiple__list-item"> <input class="js-filter-type" id="unit-type-APARTMENT|UnitSubType_NONE,DUPLEX,LOFT,STUDIO,TRIPLEX|RESIDENTIAL|APARTMENT" type="checkbox" value="APARTMENT|UnitSubType_NONE,DUPLEX,LOFT,STUDIO,TRIPLEX|RESIDENTIAL|APARTMENT"/> <label for="unit-type-APARTMENT|UnitSubType_NONE,DUPLEX,LOFT,STUDIO,TRIPLEX|RESIDENTIAL|APARTMENT">Apartamento</label> </li> <li class="select-multiple__list-item"> <input class="js-filter-type" id="unit-type-HOME|UnitSubType_NONE,SINGLE_STOREY_HOUSE,VILLAGE_HOUSE,KITNET|RESIDENTIAL|HOME" type="checkbox" value="HOME|UnitSubType_NONE,SINGLE_STOREY_HOUSE,VILLAGE_HOUSE,KITNET|RESIDENTIAL|HOME"/> <label for="unit-type-HOME|UnitSubType_NONE,SINGLE_STOREY_HOUSE,VILLAGE_HOUSE,KITNET|RESIDENTIAL|HOME">Casa</label> </li> <li class="select-multiple__list-item"> <input class="js-filter-type" id="unit-type-HOME|CONDOMINIUM|RESIDENTIAL|CONDOMINIUM" type="checkbox" value="HOME|CONDOMINIUM|RESIDENTIAL|CONDOMINIUM"/> <label for="unit-type-HOME|CONDOMINIUM|RESIDENTIAL|CONDOMINIUM">Casa de Condomínio</label> </li> <li class="select-multiple__list-item"> <input class="js-filter-type" id="unit-type-COUNTRY_HOUSE|UnitSubType_NONE|RESIDENTIAL|COUNTRY_HOUSE" type="checkbox" value="COUNTRY_HOUSE|UnitSubType_NONE|RESIDENTIAL|COUNTRY_HOUSE"/> <label for="unit-type-COUNTRY_HOUSE|UnitSubType_NONE|RESIDENTIAL|COUNTRY_HOUSE">Chácara</label> </li> <li class="select-multiple__list-item"> <input class="js-filter-type" id="unit-type-APARTMENT|PENTHOUSE|RESIDENTIAL|PENTHOUSE" type="checkbox" value="APARTMENT|PENTHOUSE|RESIDENTIAL|PENTHOUSE"/> <label for="unit-type-APARTMENT|PENTHOUSE|RESIDENTIAL|PENTHOUSE">Cobertura</label> </li> <li class="select-multiple__list-item"> <input class="js-filter-type" id="unit-type-APARTMENT|FLAT|RESIDENTIAL|FLAT" type="checkbox" value="APARTMENT|FLAT|RESIDENTIAL|FLAT"/> <label for="unit-type-APARTMENT|FLAT|RESIDENTIAL|FLAT">Flat</label> </li> <li class="select-multiple__list-item"> <input class="js-filter-type" id="unit-type-APARTMENT|KITNET|RESIDENTIAL|KITN ...
#     if (window.performance && window.performance.mark) {
#       window.performance.mark('script_start');
#     }
#
#     var settings = getSettings();
#     var App = window.App;  configureSentry(settings.portalContext);  var app = new App(settings);
#     app.start();
#   }
#
#   function getSettings () {
#     return _.assign(
#       /* Template rendering data */
#       {
#         baseUrl: '/venda/',
#         pageName: 'results',
#         legal: 'v2',
#         isPreview: Boolean(),
#         /* Remove this after migration to listing v3 */
#       },  /* Initialization Data */
#       _.assign({}, ([{"facets":{"amenities":{"SERVICE_AREA":2021527,"BARBECUE_GRILL":1930095,"POOL":1604022,"KITCHEN":1487784,"INTERCOM":1377094,"ELEVATOR":1341902,"PARTY_HALL":1263455,"BALCONY":1046353,"PLAYGROUND":1034552,"GYM":848431,"GATED_COMMUNITY":822662,"GARDEN":786570,"AIR_CONDITIONING":726056,"SPORTS_COURT":705729,"ADULT_GAME_ROOM":662629,"SAUNA":563319,"GOURMET_SPACE":561624,"LAUNDRY":548011,"BACKYARD":528546,"GARAGE":497441,"CABLE_TV":480628,"SECURITY_24_HOURS":439289,"GOURMET_BALCONY":423608,"FURNISHED":406186,"SAFETY_CIRCUIT":341471,"ALARM_SYSTEM":317305,"ADULT_POOL":252313,"HOME_OFFICE":236291,"WATCHMAN":232918,"NEAR_ACCESS_ROADS":224769,"CHILDRENS_POOL":214428,"NEAR_SHOPPING_CENTER":196451,"FIREPLACE":188677,"KITCHEN_CABINETS":187515,"NEAR_SCHOOL":185780,"DINNER_ROOM":181843,"INTERNET_ACCESS":173201,"NEAR_PUBLIC_TRANSPORT":164833,"NEAR_HOSPITAL":155262,"DEPOSIT":151818,"RECEPTION":150192,"SPA":146445,"GREEN_SPACE":136025,"TENNIS_COURT":132211,"COPA":124909,"NUMBER_OF_FLOORS":122000,"ELECTRIC_GENERATOR":101612,"BUILTIN_WARDROBE":97713,"HEATING":88210,"CLOSET":68316,"SEA_VIEW":61468,"HOME_CINEMA":61381,"YOUTH_GAME_ROOM":57453,"GRASS":56839,"FULL_CABLING":55595,"EXTERIOR_VIEW":55359,"ESSENTIAL_PUBLIC_SERVICES":53249,"TEEN_SPACE":52225,"SQUASH":42512,"MASSAGE":40933,"HIKING_TRAIL":40007,"PAY_PER_USE_SERVICES":36376,"CINEMA":31946,"MOUNTAIN_VIEW":27816,"REFLECTING_POOL":20926,"LAKE_VIEW":8758,"DISABLED_ACCESS":6342,"PETS_ALLOWED":5841,"CONCIERGE_24H":5149,"ELECTRONIC_GATE":5132,"GAMES_ROOM":5123,"GARAGE_BAND":4712,"PLAYGROUND_2":4593,"AMERICAN_KITCHEN":4498,"LARGE_ROOM":4144}},"search":{"totalCount":5604180,"currentPage":1,"result":{"listings":[{"listing":{"displayAddressType":"ALL","amenities":["CHILDRENS_POOL","ADULT_POOL","GYM","BARBECUE_GRILL","GATED_COMMUNITY","ELEVATOR","POOL","PLAYGROUND","SPORTS_COURT","PARTY_HALL","ADULT_GAME_ROOM"],"usableAreas":["101"],"constructionStatus":"ConstructionStatus_NONE","listingType":"USED","description":"1. Apartamento confortável e planta com os cômodos bem distribuídos.<br>2. Varanda gourmet espaçosa, fechada com vidros, cortina rolô e sol da manhã.<br>3. Portas de acesso social e de serviço independentes, compartilhamento do elevador social com apenas um apartamento.<br>4. Armários planejados pela empresa SCA na cozinha, lavanderia, sacada e 2 quartos.<br>5. Condomínio familiar, lazer completo: piscinas externa e coberta, salões festas e churrasqueira.<br>6. Localização próxima escola, padaria e shopping","title":"Excelente apartamento na Vila Andrade - SP","unitTypes":["APARTMENT"],"nonActivationReason":"NonActivationReason_NONE","propertyType":"UNIT","unitSubTypes":[],"id":"2476402673","portal":"GRUPOZAP","parkingSpaces":[2],"address":{"country":"BR","zipCode":"05727230","geoJson":"","city":"São Paulo","streetNumber":"695","level":"STREET","precision":"ROOFTOP","confidence":"VALID_STREET","stateAcronym":"SP","source":"CORREIOS","point":{"lon":-46.740823,"source":"GOOGLE","lat":-23.628397},"ibgeCityId":"","zone":"Zona Sul","street":"Rua Francisco Pessoa","locationId":"BR>Sao Paulo>NULL>Sao Paulo>Zona Sul>VILA ANDRADE","district":"","name":"","state":"São Paulo","neighborhood":"Vila Andrade","poisList":["BS:Rua Do Chico Nunes, 311","BS:Rua Cascado","BS:Rua Cataquena","BS:Rua Mário Linhares, 870","BS:Rua Mário Linhares, 226","TS:Rua Cascado","TS:Vila das Belezas","TS:6291-10","TS:Giovanni Gronchi","TS:Term. João Dias Lateral 2","CS:Belas Artes","CS:Angelica Empório e Rotisserie","CS:Casa Blanca","CS:Padaria Las Palmas","CS:S&m","PH:drogaria São Paulo"],"complement":"","pois":[],"valuableZones":[{"city":"São Paulo","zone":"Zona Sul","name":"Vila Andrade","id":"","state":"São Paulo","category":"DISTRICT"}]},"suites":[1],"publicationType":"PREMIUM","externalId":"32419","bathrooms":[3],"usageTypes":["RESIDENTIAL"],"totalAreas":["101"],"advertiserId":"0314716b-77ce-59ed-eeac-6c54dcd94608","bedrooms":[3],"pricingInfos":[{"rentalInfo":{"period":"MONTHLY","warranties":[]},"yearlyIp ...
#       /* Ranking Manager data */
#       {
#         /* We use sectionName because on config module we check if seccion has "IDX_" as prefix */
#         sectionName: 'IDX_VENTA' || 'results',
#       },
#       /* Feature Toogle data */  {
#           featureToggle: JSON.parse('[{"enabled":true,"groups":["website"],"id":1,"feature":"vue_lead_form"},{"enabled":true,"groups":["site"],"id":2,"feature":"googleTagManager"},{"enabled":true,"groups":["site"],"id":4,"feature":"embed_google_maps"},{"enabled":true,"groups":["site"],"id":5,"feature":"googleAnalytics"},{"enabled":true,"groups":["site"],"id":7,"feature":"dfp"},{"enabled":true,"groups":["site"],"id":10,"feature":"frontend_sentry"},{"enabled":false,"groups":["site"],"id":11,"feature":"go_page_hiding"},{"enabled":true,"groups":["canalpro"],"id":12,"feature":"android_listing_campaign_enabled"},{"enabled":true,"groups":["canalpro"],"id":13,"feature":"ios_listing_campaign_enabled"},{"enabled":false,"groups":["internal"],"id":24,"feature":"styleguide"},{"enabled":true,"groups":["site"],"id":25,"feature":"login_url_encode"},{"enabled":true,"groups":["site"],"id":42,"feature":"new_find_by_id"},{"enabled":true,"groups":["site"],"id":53,"feature":"nps"},{"enabled":true,"groups":["site"],"id":59,"feature":"google_optimize"},{"enabled":true,"groups":["site"],"id":66,"feature":"decision_tree_lead_form"},{"enabled":true,"groups":["site"],"id":67,"feature":"user_recommendations"},{"enabled":true,"groups":["site"],"id":68,"feature":"frontend_sw"},{"enabled":false,"groups":["site"],"id":123,"feature":"aldo"},{"enabled":true,"groups":["site"],"id":133,"feature":"aldo_spin"},{"enabled":true,"groups":["site"],"id":135,"feature":"results_map"},{"enabled":true,"groups":["site"],"id":137,"feature":"development_highlight"},{"enabled":true,"groups":["site"],"id":142,"feature":"streets_suggestions"},{"enabled":true,"groups":["site"],"id":144,"feature":"rp_see_phone"},{"enabled":true,"groups":["site"],"id":720,"feature":"phone_leads"},{"enabled":true,"groups":["login"],"id":998,"feature":"capitaoIntranet"},{"enabled":true,"groups":["login","zap"],"id":999,"feature":"capitaoLogin"},{"enabled":true,"groups":["canalpro"],"id":1002,"feature":"chat"},{"enabled":true,"groups":["canalpro"],"id":1003,"feature":"zapfin"},{"enabled":true,"groups":["canalpro"],"id":1004,"feature":"zapfinNew"},{"enabled":true,"groups":["canalpro"],"id":1005,"feature":"scheduler"},{"enabled":false,"groups":["canalpro"],"id":1006,"feature":"categories"},{"enabled":false,"groups":["canalpro"],"id":1007,"feature":"listingSubtype"},{"enabled":true,"groups":["canalpro"],"id":1008,"feature":"salesforceHelp"},{"enabled":true,"groups":["canalpro"],"id":1009,"feature":"whatsapp"},{"enabled":true,"groups":["site"],"id":1981,"feature":"ch_glossary_defenders"},{"enabled":true,"groups":["zap_api"],"id":1989,"feature":"send_owner_email_responsys_manco"},{"enabled":true,"groups":["login","zap"],"id":2001,"feature":"capitaoApi"},{"enabled":true,"groups":["login","zap"],"id":2002,"feature":"capitaoZapWa"},{"enabled":false,"groups":["login","zap"],"id":2003,"feature":"HistNavWrite"},{"enabled":false,"groups":["login","zap"],"id":2004,"feature":"HistNavRead"},{"enabled":true,"groups":["site"],"id":2005,"feature":"minha_casa_minha_vida"},{"enabled":true,"groups":["zap_api"],"id":2006,"feature":"send_owner_email_responsys"},{"enabled":true,"groups":["zap"],"id":2007,"feature":"stack_nova_ecommerce"},{"enabled":false,"groups":["owners"],"id":2008,"feature":"guest_checkin_privacy_term"},{"enabled":true,"groups":["anuncie"],"id":3000,"feature":"login_capitao"},{"enabled":true,"groups":["site"],"id":3003,"feature":"favoriteNewStack"},{"enabled":true,"groups":["string"],"id":3004,"feature":"newStackLDPUrl"},{"enabled":true,"groups":["site"],"id":3005,"feature":"vr_new_unit_types_filter"},{"enabled":false,"groups":["site"],"id":8005,"feature":"WriteContabMongo"},{"enabled":false,"groups":["c2c"],"id":8007,"feature":"bf_bimestral"},{"enabled":false,"groups":["site"],"id":8008,"feature":"ozassets_frontend_sentry"},{"enabled":false,"groups":["c2c"],"id":8009,"feature":"bf_trimestral"},{"enabled":false,"groups":["c2c"],"id":8010,"feature":"bf_todos"},{"enabled":false,"groups":["c2c"],"id":8011,"fe ...
#         },  /* Other data */ {"portalContext":"prod","glueApiEndpoint":"https://glue-api.vivareal.com","userInterestApiEndpoint":"https://user-interest-api.vivareal.com.br","aldoApiEndpoint":"https://api-aldo.vivareal.com.br","accountApiEndpoint":"https://account-api.grupozap.com","myAccountApiEndpoint":"https://my-account-api.vivareal.com.br","zendeskApiEndpoint":"https://zendesk-api.vivareal.com","silvioApiEndpoint":"https://silvio.vivareal.com.br","casioApiEndpoint":"https://casio-api.vivareal.com.br/","fredoEndpoint":"https://negociacao.vivareal.com.br","accountLoginUrl":"https://account-api.grupozap.com/oauth/authorize?response_type=code&source=vivareal&client_id=site&redirect_uri=https://my-account-api.vivareal.com.br/user/login?state=","loginUrl":"https://account-api.grupozap.com/oauth/authorize?response_type=code&source=vivareal&client_id=site&redirect_uri=https%3A%2F%2Fmy-account-api.vivareal.com.br%2Fuser%2Flogin%3Fstate%3D","cdnPath":"https://cdn1.vivareal.com/p/15026-153a25f35/v/static"} )
#   }  function configureSentry (env) {
#       if (env !== 'prod') return;
#
#       Raven.config('https://f47ae0f379404d47b210578238b7f3d8@sentry-logs.vivareal.com/13', {
#         whitelistUrls: [
#         /www\.vivareal\.com\.br/,
#         /staging\.vivareal\.com\.br/,
#         /dev\.vivareal\.com\.br/,
#         /cdn\d\.vivareal\.com/
#         ]
#       }).install();
#     }   if ('serviceWorker' in navigator) {
#       window.addEventListener('load', () => {
#         navigator.serviceWorker.register('/sw.js')
#           .then(registration => {
#             console.log(`Service Worker registered! Scope: ${registration.scope}`);
#           })
#           .catch(err => {
#             console.log(`Service Worker registration failed: ${err}`);
#           });
#       });
#     }  </script> <script type="application/ld+json"> {
#   "@context": "https://schema.org",
#   "@type": "Organization",
#   "name": "Viva Real",
#   "description": "O Viva Real é o maior portal de imóveis no Brasil, com mais de 4 milhões de imóveis anunciados em mais de 3 mil cidades. Acesse e encontre o imóvel dos seus sonhos!",
#
#   "address": {
#     "@type": "PostalAddress",
#     "addressCountry": {
# 	    "@type": "Country",
# 	    "name": "BR"
#     },
#     "addressLocality": "São Paulo",
#     "addressRegion": "SP",
#     "postalCode": "01415-001",
#     "streetAddress": "Rua Bela Cintra, 539 - Consolação - São Paulo - SP"
#   },
#
#   "brand": {
#     "@type": "Brand",
#     "logo": "https://cdn1.vivareal.com/p/15026-153a25f35/v/static/svg/styleguide/logo/vivareal-5bcdffca.svg"
#   },
#
#   "founder": {
#     "@type": "Person",
#     "givenName": "Brian",
#     "familyName": "Requarth",
#     "jobTitle": "CEO"
#   },
#
#   "telephone": "+55 11 3150-4646",
#   "URL": "https://www.vivareal.com.br/"
# } </script> <script data-cf-settings="bf948744663da505b3bdeb50-|49" defer="" src="https://ajax.cloudflare.com/cdn-cgi/scripts/7089c43e/cloudflare-static/rocket-loader.min.js"></script></body> </html>

# %%
imoveis = analizador.find_all('div', class_="js-card-selector")

# %% [markdown]
# Vamos dar uma olhadinha no que tem dentro de cada ítem do array:

# %%
for i in imoveis[:5]:
    print(str(i).replace("\n","").replace("   ","")[:200] + "…\n")
# Out:
# <div class="js-card-selector"> <article class="property-card__container js-property-card" data-see-phone=""> <div class="property-card__main-info"> <div class="property-card__main-link"> <div class="p…
#
# <div class="js-card-selector"> <article class="property-card__container js-property-card" data-see-phone=""> <div class="property-card__main-info"> <div class="property-card__main-link"> <div class="p…
#
# <div class="js-card-selector"> <article class="property-card__container js-property-card" data-see-phone=""> <div class="property-card__main-info"> <div class="property-card__main-link"> <div class="p…
#
# <div class="js-card-selector"> <article class="property-card__container js-property-card" data-see-phone=""> <div class="property-card__main-info"> <div class="property-card__main-link"> <div class="p…
#
# <div class="js-card-selector"> <article class="property-card__container js-property-card" data-see-phone=""> <div class="property-card__main-info"> <div class="property-card__main-link"> <div class="p…

# %%
len(imoveis)
# Out:
# 36

# %% [markdown]
# ### Passo 3: Monto receitas para extrair cada dado que desejo
#
# Ótimo. Agora olhando a estrutura de tags e atributos, uso seletores para isolar exatamente o dado que desejo. Após isolá-lo, ainda forço ele a passar por filtros para eliminar inutilidades como espaços (uso `strip()`), prefixos como "R$ " (uso `replace("R$ ","")`) e ajusto o ponto decimal de números (uso `replace(".","")`) para em seguida convertê-los de texto para números (uso `int()`).
#
# É muito importante para mim também obter o ID do imóvel. Como esta informação está num atributo do `<div>` pai, uso o seletor `parent`.

# %%
# Título do anúncio
print(imoveis[0].find("span",class_="property-card__title").contents[0].strip())
# Out:
# Apartamento com 3 Quartos à Venda, 101m²

# %%
# Endereço
print(imoveis[0].find("span",class_="property-card__address").contents[0].strip())
# Out:
# Rua Francisco Pessoa, 695 - Vila Andrade, São Paulo - SP

# %%
imoveis[0].find("div",class_="property-card__price").find("p").contents[0].strip().replace("R$ ","").replace(".","")
# Out:
# '750000'

# %%
float(imoveis[0].find("div",class_="property-card__price").find("p").contents[0].strip().replace("R$ ","").replace(".",""))
# Out:
# 750000.0

# %%
# Preço limpo e transformado em inteiro
print(int(imoveis[0].find("div",class_="property-card__price").find("p").contents[0].strip().replace("R$ ","").replace(".","")))
# Out:
# 750000

# %%
# Telefone
try:
    print(imoveis[0].find("a",class_="property-card__contact--phone").get('href').replace("tel:","+55"))
except:
    pass

# %%
# Amenidades
try:
  print(imoveis[0].find('ul',class_="property-card__amenities").text.strip().replace('...', ''))
except:
  pass
# Out:
# Elevador Piscina Churrasqueira Salão de festas Playground

# %%
# Texto descritivo
try:
    print(imoveis[0].find('ul',class_='property-card__details').text.strip())
except:
    pass
# Out:
# 101   m²     3   Quartos     3   Banheiros     2   Vagas

# %%
print(int(imoveis[0].find('ul',class_='property-card__details').find('span',class_='property-card__detail-area').text.strip()))
# Out:
# 101

# %%
# imoveis[0].find('div',class_='property-card__description').contents[0].strip()

# ID do imovel
print(imoveis[0].parent.get('id'))
# Out:
# 2476402673

# %% [markdown]
# ## Extração em massa
#
# Depois da análise acima, podemos criar nosso loop que consome todo o site. Página por página, imóvel por imóvel, dado por dado.

# %%
# são 277 páginas de imóveis a venda no total
# paginas=277

# mas a título de exemplo, usaremos somente 20 páginas:
paginas=20

# %%
# em rows guardo uma lista temporária de dicts de dados capturados, 1 dict por imóvel
imóveis=[]

for pagina in range(1,paginas+1):
    print("Estou aqui: " + url.format(npagina=pagina))
    
    # pega a página do site pela internet
    doc = requests.get(url.format(npagina=pagina))
    
    # analiza o HTML
    analizador = BeautifulSoup(doc.content, 'html.parser')
    
    # extrai somente a lista de imóveis (em HTML) usando o seletor descoberto no código da página
    imoveis = analizador.find_all('div', class_="js-card-selector")
    
    for unidade in imoveis:
        uni={}
        # extrai dado por dado segundo seus seletores...
        
        # O ID:
        uni['id'] = unidade.parent.get('id')
        
        # O título/nome:
        uni['nome']  = unidade.find("span",class_="property-card__title").contents[0].strip()
        
        # O endereço:
        uni['ende']  = unidade.find("span",class_="property-card__address").contents[0].strip()
        
        # A metragem
        uni['metragem']=int(unidade.find('ul',class_='property-card__details').find('span',class_='property-card__detail-area').text.strip())
        
        # O preço tem uma pegadinha
        try:
            # Na maioria dos anuncios o preço está na posição 0.
            # Mas em alguns, o preço aparece como "a partir de" e causa um erro aqui.
            uni['preco'] = int(unidade.find("div",class_="property-card__price").find("p").contents[0].strip().replace("R$ ","").replace(".",""))
        except ValueError:
            # Então o meu tratamento de erro para preços "a partir de" é tentar capturá-lo na posição 2:
            try:
                uni['preco'] = int(unidade.find("div",class_="property-card__price").contents[2].strip().replace("R$ ","").replace(".",""))
            except IndexError:
                # Mas há um outro tipo de problema, onde o preço aparece "sob consulta", e causa um "IndexError". Trato assim:
                uni['preco'] = -1

        # O telefone capturo manipulando a URL e dando uma internacionalizada básica com "+55":
        try:
            uni['tel'] = unidade.find("a",class_="property-card__contact--phone").get('href').replace("tel:","+55")
        except:
            pass
        
        # A descrição:
        try:
            uni['desc'] = unidade.find('ul',class_='property-card__details').text.strip()
        except:
            pass
        
        # Amenidades
        try:
          uni['amenidades'] = unidade.find('ul',class_="property-card__amenities").text.strip().replace('...', '')
        except:
          pass

        # No final deste loop, o dict uni contém os dados de 1 imóvel, aí adiciono-o a uma lista de imóveis
        imóveis.append(uni)
# Out:
# Estou aqui: https://www.vivareal.com.br/venda/?pagina=1
# Estou aqui: https://www.vivareal.com.br/venda/?pagina=2
# Estou aqui: https://www.vivareal.com.br/venda/?pagina=3
# Estou aqui: https://www.vivareal.com.br/venda/?pagina=4
# Estou aqui: https://www.vivareal.com.br/venda/?pagina=5
# Estou aqui: https://www.vivareal.com.br/venda/?pagina=6
# Estou aqui: https://www.vivareal.com.br/venda/?pagina=7
# Estou aqui: https://www.vivareal.com.br/venda/?pagina=8
# Estou aqui: https://www.vivareal.com.br/venda/?pagina=9
# Estou aqui: https://www.vivareal.com.br/venda/?pagina=10
# Estou aqui: https://www.vivareal.com.br/venda/?pagina=11
# Estou aqui: https://www.vivareal.com.br/venda/?pagina=12
# Estou aqui: https://www.vivareal.com.br/venda/?pagina=13
# Estou aqui: https://www.vivareal.com.br/venda/?pagina=14
# Estou aqui: https://www.vivareal.com.br/venda/?pagina=15
# Estou aqui: https://www.vivareal.com.br/venda/?pagina=16
# Estou aqui: https://www.vivareal.com.br/venda/?pagina=17
# Estou aqui: https://www.vivareal.com.br/venda/?pagina=18
# Estou aqui: https://www.vivareal.com.br/venda/?pagina=19
# Estou aqui: https://www.vivareal.com.br/venda/?pagina=20

# %% [markdown]
# Processei todos os imóveis de todas as páginas. Vamos ver o resultado...

# %%
imóveis
# Out:
# [{'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '101   m²     3   Quartos     3   Banheiros     2   Vagas',
#   'ende': 'Rua Francisco Pessoa, 695 - Vila Andrade, São Paulo - SP',
#   'id': '2476402673',
#   'metragem': 101,
#   'nome': 'Apartamento com 3 Quartos à Venda, 101m²',
#   'preco': 750000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Academia ',
#   'desc': '107   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Paris, 241 - Sumaré, São Paulo - SP',
#   'id': '2473758281',
#   'metragem': 107,
#   'nome': 'Apartamento com 3 Quartos à Venda, 107m²',
#   'preco': 850000},
#  {'amenidades': 'Mobiliado Elevador Piscina Área de serviço Churrasqueira ',
#   'desc': '70   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Cipriano Barata, 790 - Ipiranga, São Paulo - SP',
#   'id': '2475837894',
#   'metragem': 70,
#   'nome': 'Apartamento com 2 Quartos à Venda, 70m²',
#   'preco': 565000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Salão de festas ',
#   'desc': '57   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Cônego Vicente Miguel Marino, 183 - Barra Funda, São Paulo - SP',
#   'id': '2476743581',
#   'metragem': 57,
#   'nome': 'Apartamento com 2 Quartos à Venda, 57m²',
#   'preco': 490000},
#  {'amenidades': 'Elevador Academia Condomínio fechado',
#   'desc': '290   m²     6   Quartos     5   Banheiros     2   Vagas',
#   'ende': 'Alameda Tietê, 325 - Jardim Paulista, São Paulo - SP',
#   'id': '2477112488',
#   'metragem': 290,
#   'nome': 'Apartamento com 6 Quartos à Venda, 290m²',
#   'preco': 3000000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Salão de festas ',
#   'desc': '48   m²     1   Quarto     2   Banheiros     1   Vaga',
#   'ende': 'Rua Major Quedinho, 224 - Centro, São Paulo - SP',
#   'id': '2476286177',
#   'metragem': 48,
#   'nome': 'Apartamento com  Quarto à Venda, 48m²',
#   'preco': 600000},
#  {'amenidades': 'Elevador Piscina Área de serviço Churrasqueira Salão de festas ',
#   'desc': '93   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Cônego Vicente Miguel Marino, 175 - Barra Funda, São Paulo - SP',
#   'id': '2476274799',
#   'metragem': 93,
#   'nome': 'Apartamento com 3 Quartos à Venda, 93m²',
#   'preco': 600000},
#  {'amenidades': 'Elevador Piscina Salão de festas Playground Academia ',
#   'desc': '160   m²     3   Quartos     3   Banheiros     2   Vagas',
#   'ende': 'Rua André Dreyfus, 109 - Sumaré, São Paulo - SP',
#   'id': '2473759712',
#   'metragem': 160,
#   'nome': 'Apartamento com 3 Quartos à Venda, 160m²',
#   'preco': 1300000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '84   m²     1   Quarto     2   Banheiros     1   Vaga',
#   'ende': 'Rua Turiassu, 507 - Perdizes, São Paulo - SP',
#   'id': '2476277377',
#   'metragem': 84,
#   'nome': 'Apartamento com  Quarto à Venda, 84m²',
#   'preco': 1060000},
#  {'amenidades': 'Churrasqueira Salão de festas Playground Academia Sauna ',
#   'desc': '93   m²     1   Quarto     2   Banheiros     2   Vagas',
#   'ende': 'Rua Marechal Hermes da Fonseca, 600 - Santana, São Paulo - SP',
#   'id': '2476266182',
#   'metragem': 93,
#   'nome': 'Apartamento com  Quarto à Venda, 93m²',
#   'preco': 900000},
#  {'amenidades': 'Mobiliado',
#   'desc': '80   m²     2   Quartos     2   Banheiros     --   Vaga',
#   'ende': 'Avenida Nove de Julho, 1050 - Bela Vista, São Paulo - SP',
#   'id': '2476258295',
#   'metragem': 80,
#   'nome': 'Apartamento com 2 Quartos à Venda, 80m²',
#   'preco': 539000},
#  {'amenidades': 'Elevador Salão de festas Jardim Condomínio fechado Escritório',
#   'desc': '97   m²     2   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Itambé, 440 - Higienópolis, São Paulo - SP',
#   'id': '2477014085',
#   'metragem': 97,
#   'nome': 'Apartamento com 2 Quartos à Venda, 97m²',
#   'preco': 980000},
#  {'desc': '290   m²     6   Quartos     5   Banheiros     3   Vagas',
#   'ende': 'Rua Apinajés, 1896 - Sumaré, São Paulo - SP',
#   'id': '2473930912',
#   'metragem': 290,
#   'nome': 'Sobrado com 6 Quartos à Venda, 290m²',
#   'preco': 1590000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '58   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Torres da Barra, 99 - Água Branca, São Paulo - SP',
#   'id': '2495239876',
#   'metragem': 58,
#   'nome': 'Apartamento com 2 Quartos à Venda, 58m²',
#   'preco': 421900},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '58   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Torres da Barra, 99 - Água Branca, São Paulo - SP',
#   'id': '2495229291',
#   'metragem': 58,
#   'nome': 'Apartamento com 2 Quartos à Venda, 58m²',
#   'preco': 403900},
#  {'amenidades': 'Mobiliado Elevador Piscina Área de serviço Churrasqueira ',
#   'desc': '140   m²     3   Quartos     5   Banheiros     2   Vagas',
#   'ende': 'Rua 146, 147 - Setor Marista, Goiânia - GO',
#   'id': '2485814349',
#   'metragem': 140,
#   'nome': 'Apartamento com 3 Quartos à Venda, 140m²',
#   'preco': 699999},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Academia ',
#   'desc': '82   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Buenos Aires, 39 - Jardim das Américas, Cuiabá - MT',
#   'id': '2499704784',
#   'metragem': 82,
#   'nome': 'Apartamento com 3 Quartos à Venda, 82m²',
#   'preco': 390000},
#  {'desc': '48   m²     2   Quartos     1   Banheiro     1   Vaga',
#   'ende': 'Avenida Padre Estanislau de Campos, 87 - Conjunto Habitacional Padre Manoel da Nóbrega, São Paulo - SP',
#   'id': '2501381225',
#   'metragem': 48,
#   'nome': 'Apartamento com 2 Quartos à Venda, 48m²',
#   'preco': 199000},
#  {'amenidades': 'Elevador Piscina Área de serviço Churrasqueira Salão de festas ',
#   'desc': '95   m²     3   Quartos     4   Banheiros     2   Vagas',
#   'ende': 'Rua T 33, 1 - Setor Bueno, Goiânia - GO',
#   'id': '2484719668',
#   'metragem': 95,
#   'nome': 'Apartamento com 3 Quartos à Venda, 95m²',
#   'preco': 539999},
#  {'amenidades': 'Mobiliado Elevador Piscina Academia Ar-condicionado ',
#   'desc': '26   m²     1   Quarto     1   Banheiro     1   Vaga',
#   'ende': 'Avenida Sabiá, , 825 - Indianópolis, São Paulo - SP',
#   'id': '2493994987',
#   'metragem': 26,
#   'nome': 'Flat com  Quarto para Venda/Aluguel 26m²',
#   'preco': 2000},
#  {'amenidades': 'Piscina Área de serviço Churrasqueira Varanda Ar-condicionado ',
#   'desc': '77   m²     3   Quartos     3   Banheiros     2   Vagas',
#   'ende': 'Rua Artur Thiré - Vila da Saúde, São Paulo - SP',
#   'id': '2494214252',
#   'metragem': 77,
#   'nome': 'Apartamento com 3 Quartos à Venda, 77m²',
#   'preco': 680000},
#  {'amenidades': 'Mobiliado Churrasqueira Jardim Ar-condicionado Condomínio fechado ',
#   'desc': '76   m²     3   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Benedito Cardoso Adriano Filho, 100 - Enseada, Guarujá - SP',
#   'id': '2494152308',
#   'metragem': 76,
#   'nome': 'Apartamento com 3 Quartos à Venda, 76m²',
#   'preco': 272000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Ar-condicionado ',
#   'desc': '70   m²     3   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Marivaldo Fernandes, 270 - Enseada, Guarujá - SP',
#   'id': '2474593494',
#   'metragem': 70,
#   'nome': 'Apartamento com 3 Quartos à Venda, 70m²',
#   'preco': 350000},
#  {'desc': '341   m²     4   Quartos     6   Banheiros     4   Vagas',
#   'ende': 'Rua Capitão Alberto Mendes Júnior, 31 - Loteamento Vale Azul I, Jundiaí - SP',
#   'id': '2494336886',
#   'metragem': 341,
#   'nome': 'Casa de condomínio com 4 Quartos à Venda, 341m²',
#   'preco': 1680000},
#  {'amenidades': 'Elevador Churrasqueira Salão de festas Playground Academia ',
#   'desc': '74   m²     3   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Engenheiro Arthur Bettes, 75 - Portão, Curitiba - PR',
#   'id': '2500866017',
#   'metragem': 74,
#   'nome': 'Apartamento com 3 Quartos à Venda, 74m²',
#   'preco': 430000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '64   m²     3   Quartos     1   Banheiro     1   Vaga',
#   'ende': 'Avenida Moinho Fabrini, 385 - Independência, São Bernardo do Campo - SP',
#   'id': '2499614983',
#   'metragem': 64,
#   'nome': 'Apartamento com 3 Quartos à Venda, 64m²',
#   'preco': 405000},
#  {'amenidades': 'Piscina Salão de festas Salão de jogos Aceita animais Salão de jogos ',
#   'desc': '68   m²     2   Quartos     1   Banheiro     1   Vaga',
#   'ende': 'Rua Colômbia, 454 - Guilhermina, Praia Grande - SP',
#   'id': '2501074481',
#   'metragem': 68,
#   'nome': 'Apartamento com 2 Quartos à Venda, 68m²',
#   'preco': 260000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Salão de festas ',
#   'desc': '74   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua dos Jequitibás - Campestre, Santo André - SP',
#   'id': '2500839600',
#   'metragem': 74,
#   'nome': 'Apartamento com 3 Quartos à Venda, 74m²',
#   'preco': 480000},
#  {'amenidades': 'Elevador Piscina Área de serviço Churrasqueira Salão de festas ',
#   'desc': '162   m²     3   Quartos     4   Banheiros     3   Vagas',
#   'ende': 'Avenida José Medeiros Vieira, 1876 - Praia Brava de Itajaí, Itajaí - SC',
#   'id': '2499833175',
#   'metragem': 162,
#   'nome': 'Apartamento com 3 Quartos à Venda, 162m²',
#   'preco': 1740000},
#  {'amenidades': 'Mobiliado Elevador Churrasqueira Salão de festas Playground ',
#   'desc': '55   m²     2   Quartos     1   Banheiro     1   Vaga',
#   'ende': 'Rua Carolina Fonseca, 315 - Vila Santana, São Paulo - SP',
#   'id': '2501209491',
#   'metragem': 55,
#   'nome': 'Apartamento com 2 Quartos à Venda, 55m²',
#   'preco': 220000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '79   m²     3   Quartos     3   Banheiros     1   Vaga',
#   'ende': 'Travessa Magno de Araújo, 370 - Telégrafo Sem Fio, Belém - PA',
#   'id': '2502667901',
#   'metragem': 79,
#   'nome': 'Apartamento com 3 Quartos à Venda, 79m²',
#   'preco': 453960},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '80   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Marte - Jardim Tupanci, Barueri - SP',
#   'id': '2495987482',
#   'metragem': 80,
#   'nome': 'Apartamento com 3 Quartos à Venda, 80m²',
#   'preco': 387000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Salão de festas ',
#   'desc': '90   m²     3   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Mathias Velho, 97 - Centro, Canoas - RS',
#   'id': '2490600476',
#   'metragem': 90,
#   'nome': 'Apartamento com 3 Quartos à Venda, 90m²',
#   'preco': 410000},
#  {'amenidades': 'Varanda',
#   'desc': '83   m²     2   Quartos     3   Banheiros     1   Vaga',
#   'ende': 'Rua Raposo Tavares, 102 - Jardim das Acácias, São Paulo - SP',
#   'id': '2498679480',
#   'metragem': 83,
#   'nome': 'Apartamento com 2 Quartos à Venda, 83m²',
#   'preco': 680000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '62   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Godofredo Fraga, 10 - Marapé, Santos - SP',
#   'id': '2501376484',
#   'metragem': 62,
#   'nome': 'Apartamento com 2 Quartos à Venda, 62m²',
#   'preco': 367000},
#  {'amenidades': 'Elevador Piscina Área de serviço Churrasqueira Salão de festas ',
#   'desc': '120   m²     3   Quartos     4   Banheiros     2   Vagas',
#   'ende': 'Rua 246, 423 - Andorinha, Itapema - SC',
#   'id': '2496574477',
#   'metragem': 120,
#   'nome': 'Apartamento com 3 Quartos à Venda, 120m²',
#   'preco': 719000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '101   m²     3   Quartos     3   Banheiros     2   Vagas',
#   'ende': 'Rua Francisco Pessoa, 695 - Vila Andrade, São Paulo - SP',
#   'id': '2476402673',
#   'metragem': 101,
#   'nome': 'Apartamento com 3 Quartos à Venda, 101m²',
#   'preco': 750000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Academia ',
#   'desc': '107   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Paris, 241 - Sumaré, São Paulo - SP',
#   'id': '2473758281',
#   'metragem': 107,
#   'nome': 'Apartamento com 3 Quartos à Venda, 107m²',
#   'preco': 850000},
#  {'amenidades': 'Mobiliado Elevador Piscina Área de serviço Churrasqueira ',
#   'desc': '70   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Cipriano Barata, 790 - Ipiranga, São Paulo - SP',
#   'id': '2475837894',
#   'metragem': 70,
#   'nome': 'Apartamento com 2 Quartos à Venda, 70m²',
#   'preco': 565000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Salão de festas ',
#   'desc': '57   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Cônego Vicente Miguel Marino, 183 - Barra Funda, São Paulo - SP',
#   'id': '2476743581',
#   'metragem': 57,
#   'nome': 'Apartamento com 2 Quartos à Venda, 57m²',
#   'preco': 490000},
#  {'amenidades': 'Elevador Academia Condomínio fechado',
#   'desc': '290   m²     6   Quartos     5   Banheiros     2   Vagas',
#   'ende': 'Alameda Tietê, 325 - Jardim Paulista, São Paulo - SP',
#   'id': '2477112488',
#   'metragem': 290,
#   'nome': 'Apartamento com 6 Quartos à Venda, 290m²',
#   'preco': 3000000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Salão de festas ',
#   'desc': '48   m²     1   Quarto     2   Banheiros     1   Vaga',
#   'ende': 'Rua Major Quedinho, 224 - Centro, São Paulo - SP',
#   'id': '2476286177',
#   'metragem': 48,
#   'nome': 'Apartamento com  Quarto à Venda, 48m²',
#   'preco': 600000},
#  {'amenidades': 'Elevador Piscina Área de serviço Churrasqueira Salão de festas ',
#   'desc': '93   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Cônego Vicente Miguel Marino, 175 - Barra Funda, São Paulo - SP',
#   'id': '2476274799',
#   'metragem': 93,
#   'nome': 'Apartamento com 3 Quartos à Venda, 93m²',
#   'preco': 600000},
#  {'amenidades': 'Elevador Piscina Salão de festas Playground Academia ',
#   'desc': '160   m²     3   Quartos     3   Banheiros     2   Vagas',
#   'ende': 'Rua André Dreyfus, 109 - Sumaré, São Paulo - SP',
#   'id': '2473759712',
#   'metragem': 160,
#   'nome': 'Apartamento com 3 Quartos à Venda, 160m²',
#   'preco': 1300000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '84   m²     1   Quarto     2   Banheiros     1   Vaga',
#   'ende': 'Rua Turiassu, 507 - Perdizes, São Paulo - SP',
#   'id': '2476277377',
#   'metragem': 84,
#   'nome': 'Apartamento com  Quarto à Venda, 84m²',
#   'preco': 1060000},
#  {'amenidades': 'Churrasqueira Salão de festas Playground Academia Sauna ',
#   'desc': '93   m²     1   Quarto     2   Banheiros     2   Vagas',
#   'ende': 'Rua Marechal Hermes da Fonseca, 600 - Santana, São Paulo - SP',
#   'id': '2476266182',
#   'metragem': 93,
#   'nome': 'Apartamento com  Quarto à Venda, 93m²',
#   'preco': 900000},
#  {'amenidades': 'Mobiliado',
#   'desc': '80   m²     2   Quartos     2   Banheiros     --   Vaga',
#   'ende': 'Avenida Nove de Julho, 1050 - Bela Vista, São Paulo - SP',
#   'id': '2476258295',
#   'metragem': 80,
#   'nome': 'Apartamento com 2 Quartos à Venda, 80m²',
#   'preco': 539000},
#  {'amenidades': 'Elevador Salão de festas Jardim Condomínio fechado Escritório',
#   'desc': '97   m²     2   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Itambé, 440 - Higienópolis, São Paulo - SP',
#   'id': '2477014085',
#   'metragem': 97,
#   'nome': 'Apartamento com 2 Quartos à Venda, 97m²',
#   'preco': 980000},
#  {'desc': '290   m²     6   Quartos     5   Banheiros     3   Vagas',
#   'ende': 'Rua Apinajés, 1896 - Sumaré, São Paulo - SP',
#   'id': '2473930912',
#   'metragem': 290,
#   'nome': 'Sobrado com 6 Quartos à Venda, 290m²',
#   'preco': 1590000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '58   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Torres da Barra, 99 - Água Branca, São Paulo - SP',
#   'id': '2495239876',
#   'metragem': 58,
#   'nome': 'Apartamento com 2 Quartos à Venda, 58m²',
#   'preco': 421900},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '58   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Torres da Barra, 99 - Água Branca, São Paulo - SP',
#   'id': '2495229291',
#   'metragem': 58,
#   'nome': 'Apartamento com 2 Quartos à Venda, 58m²',
#   'preco': 403900},
#  {'amenidades': 'Mobiliado Elevador Piscina Área de serviço Churrasqueira ',
#   'desc': '140   m²     3   Quartos     5   Banheiros     2   Vagas',
#   'ende': 'Rua 146, 147 - Setor Marista, Goiânia - GO',
#   'id': '2485814349',
#   'metragem': 140,
#   'nome': 'Apartamento com 3 Quartos à Venda, 140m²',
#   'preco': 699999},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Academia ',
#   'desc': '82   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Buenos Aires, 39 - Jardim das Américas, Cuiabá - MT',
#   'id': '2499704784',
#   'metragem': 82,
#   'nome': 'Apartamento com 3 Quartos à Venda, 82m²',
#   'preco': 390000},
#  {'desc': '48   m²     2   Quartos     1   Banheiro     1   Vaga',
#   'ende': 'Avenida Padre Estanislau de Campos, 87 - Conjunto Habitacional Padre Manoel da Nóbrega, São Paulo - SP',
#   'id': '2501381225',
#   'metragem': 48,
#   'nome': 'Apartamento com 2 Quartos à Venda, 48m²',
#   'preco': 199000},
#  {'amenidades': 'Elevador Piscina Área de serviço Churrasqueira Salão de festas ',
#   'desc': '95   m²     3   Quartos     4   Banheiros     2   Vagas',
#   'ende': 'Rua T 33, 1 - Setor Bueno, Goiânia - GO',
#   'id': '2484719668',
#   'metragem': 95,
#   'nome': 'Apartamento com 3 Quartos à Venda, 95m²',
#   'preco': 539999},
#  {'amenidades': 'Mobiliado Elevador Piscina Academia Ar-condicionado ',
#   'desc': '26   m²     1   Quarto     1   Banheiro     1   Vaga',
#   'ende': 'Avenida Sabiá, , 825 - Indianópolis, São Paulo - SP',
#   'id': '2493994987',
#   'metragem': 26,
#   'nome': 'Flat com  Quarto para Venda/Aluguel 26m²',
#   'preco': 2000},
#  {'amenidades': 'Piscina Área de serviço Churrasqueira Varanda Ar-condicionado ',
#   'desc': '77   m²     3   Quartos     3   Banheiros     2   Vagas',
#   'ende': 'Rua Artur Thiré - Vila da Saúde, São Paulo - SP',
#   'id': '2494214252',
#   'metragem': 77,
#   'nome': 'Apartamento com 3 Quartos à Venda, 77m²',
#   'preco': 680000},
#  {'amenidades': 'Mobiliado Churrasqueira Jardim Ar-condicionado Condomínio fechado ',
#   'desc': '76   m²     3   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Benedito Cardoso Adriano Filho, 100 - Enseada, Guarujá - SP',
#   'id': '2494152308',
#   'metragem': 76,
#   'nome': 'Apartamento com 3 Quartos à Venda, 76m²',
#   'preco': 272000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Ar-condicionado ',
#   'desc': '70   m²     3   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Marivaldo Fernandes, 270 - Enseada, Guarujá - SP',
#   'id': '2474593494',
#   'metragem': 70,
#   'nome': 'Apartamento com 3 Quartos à Venda, 70m²',
#   'preco': 350000},
#  {'desc': '341   m²     4   Quartos     6   Banheiros     4   Vagas',
#   'ende': 'Rua Capitão Alberto Mendes Júnior, 31 - Loteamento Vale Azul I, Jundiaí - SP',
#   'id': '2494336886',
#   'metragem': 341,
#   'nome': 'Casa de condomínio com 4 Quartos à Venda, 341m²',
#   'preco': 1680000},
#  {'amenidades': 'Elevador Churrasqueira Salão de festas Playground Academia ',
#   'desc': '74   m²     3   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Engenheiro Arthur Bettes, 75 - Portão, Curitiba - PR',
#   'id': '2500866017',
#   'metragem': 74,
#   'nome': 'Apartamento com 3 Quartos à Venda, 74m²',
#   'preco': 430000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '64   m²     3   Quartos     1   Banheiro     1   Vaga',
#   'ende': 'Avenida Moinho Fabrini, 385 - Independência, São Bernardo do Campo - SP',
#   'id': '2499614983',
#   'metragem': 64,
#   'nome': 'Apartamento com 3 Quartos à Venda, 64m²',
#   'preco': 405000},
#  {'amenidades': 'Piscina Salão de festas Salão de jogos Aceita animais Salão de jogos ',
#   'desc': '68   m²     2   Quartos     1   Banheiro     1   Vaga',
#   'ende': 'Rua Colômbia, 454 - Guilhermina, Praia Grande - SP',
#   'id': '2501074481',
#   'metragem': 68,
#   'nome': 'Apartamento com 2 Quartos à Venda, 68m²',
#   'preco': 260000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Salão de festas ',
#   'desc': '74   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua dos Jequitibás - Campestre, Santo André - SP',
#   'id': '2500839600',
#   'metragem': 74,
#   'nome': 'Apartamento com 3 Quartos à Venda, 74m²',
#   'preco': 480000},
#  {'amenidades': 'Elevador Piscina Área de serviço Churrasqueira Salão de festas ',
#   'desc': '162   m²     3   Quartos     4   Banheiros     3   Vagas',
#   'ende': 'Avenida José Medeiros Vieira, 1876 - Praia Brava de Itajaí, Itajaí - SC',
#   'id': '2499833175',
#   'metragem': 162,
#   'nome': 'Apartamento com 3 Quartos à Venda, 162m²',
#   'preco': 1740000},
#  {'amenidades': 'Mobiliado Elevador Churrasqueira Salão de festas Playground ',
#   'desc': '55   m²     2   Quartos     1   Banheiro     1   Vaga',
#   'ende': 'Rua Carolina Fonseca, 315 - Vila Santana, São Paulo - SP',
#   'id': '2501209491',
#   'metragem': 55,
#   'nome': 'Apartamento com 2 Quartos à Venda, 55m²',
#   'preco': 220000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '79   m²     3   Quartos     3   Banheiros     1   Vaga',
#   'ende': 'Travessa Magno de Araújo, 370 - Telégrafo Sem Fio, Belém - PA',
#   'id': '2502667901',
#   'metragem': 79,
#   'nome': 'Apartamento com 3 Quartos à Venda, 79m²',
#   'preco': 453960},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '80   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Marte - Jardim Tupanci, Barueri - SP',
#   'id': '2495987482',
#   'metragem': 80,
#   'nome': 'Apartamento com 3 Quartos à Venda, 80m²',
#   'preco': 387000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Salão de festas ',
#   'desc': '90   m²     3   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Mathias Velho, 97 - Centro, Canoas - RS',
#   'id': '2490600476',
#   'metragem': 90,
#   'nome': 'Apartamento com 3 Quartos à Venda, 90m²',
#   'preco': 410000},
#  {'amenidades': 'Varanda',
#   'desc': '83   m²     2   Quartos     3   Banheiros     1   Vaga',
#   'ende': 'Rua Raposo Tavares, 102 - Jardim das Acácias, São Paulo - SP',
#   'id': '2498679480',
#   'metragem': 83,
#   'nome': 'Apartamento com 2 Quartos à Venda, 83m²',
#   'preco': 680000},
#  {'amenidades': 'Elevador Piscina Área de serviço Churrasqueira Salão de festas ',
#   'desc': '120   m²     3   Quartos     4   Banheiros     2   Vagas',
#   'ende': 'Rua 246, 423 - Andorinha, Itapema - SC',
#   'id': '2496574477',
#   'metragem': 120,
#   'nome': 'Apartamento com 3 Quartos à Venda, 120m²',
#   'preco': 719000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '70   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Teixeira Heizer, 1965 - Recreio dos Bandeirantes, Rio de Janeiro - RJ',
#   'id': '2492689561',
#   'metragem': 70,
#   'nome': 'Apartamento com 2 Quartos à Venda, 70m²',
#   'preco': 380000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '101   m²     3   Quartos     3   Banheiros     2   Vagas',
#   'ende': 'Rua Francisco Pessoa, 695 - Vila Andrade, São Paulo - SP',
#   'id': '2476402673',
#   'metragem': 101,
#   'nome': 'Apartamento com 3 Quartos à Venda, 101m²',
#   'preco': 750000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Academia ',
#   'desc': '107   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Paris, 241 - Sumaré, São Paulo - SP',
#   'id': '2473758281',
#   'metragem': 107,
#   'nome': 'Apartamento com 3 Quartos à Venda, 107m²',
#   'preco': 850000},
#  {'amenidades': 'Mobiliado Elevador Piscina Área de serviço Churrasqueira ',
#   'desc': '70   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Cipriano Barata, 790 - Ipiranga, São Paulo - SP',
#   'id': '2475837894',
#   'metragem': 70,
#   'nome': 'Apartamento com 2 Quartos à Venda, 70m²',
#   'preco': 565000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Salão de festas ',
#   'desc': '57   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Cônego Vicente Miguel Marino, 183 - Barra Funda, São Paulo - SP',
#   'id': '2476743581',
#   'metragem': 57,
#   'nome': 'Apartamento com 2 Quartos à Venda, 57m²',
#   'preco': 490000},
#  {'amenidades': 'Elevador Academia Condomínio fechado',
#   'desc': '290   m²     6   Quartos     5   Banheiros     2   Vagas',
#   'ende': 'Alameda Tietê, 325 - Jardim Paulista, São Paulo - SP',
#   'id': '2477112488',
#   'metragem': 290,
#   'nome': 'Apartamento com 6 Quartos à Venda, 290m²',
#   'preco': 3000000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Salão de festas ',
#   'desc': '48   m²     1   Quarto     2   Banheiros     1   Vaga',
#   'ende': 'Rua Major Quedinho, 224 - Centro, São Paulo - SP',
#   'id': '2476286177',
#   'metragem': 48,
#   'nome': 'Apartamento com  Quarto à Venda, 48m²',
#   'preco': 600000},
#  {'amenidades': 'Elevador Piscina Área de serviço Churrasqueira Salão de festas ',
#   'desc': '93   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Cônego Vicente Miguel Marino, 175 - Barra Funda, São Paulo - SP',
#   'id': '2476274799',
#   'metragem': 93,
#   'nome': 'Apartamento com 3 Quartos à Venda, 93m²',
#   'preco': 600000},
#  {'amenidades': 'Elevador Piscina Salão de festas Playground Academia ',
#   'desc': '160   m²     3   Quartos     3   Banheiros     2   Vagas',
#   'ende': 'Rua André Dreyfus, 109 - Sumaré, São Paulo - SP',
#   'id': '2473759712',
#   'metragem': 160,
#   'nome': 'Apartamento com 3 Quartos à Venda, 160m²',
#   'preco': 1300000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '84   m²     1   Quarto     2   Banheiros     1   Vaga',
#   'ende': 'Rua Turiassu, 507 - Perdizes, São Paulo - SP',
#   'id': '2476277377',
#   'metragem': 84,
#   'nome': 'Apartamento com  Quarto à Venda, 84m²',
#   'preco': 1060000},
#  {'amenidades': 'Churrasqueira Salão de festas Playground Academia Sauna ',
#   'desc': '93   m²     1   Quarto     2   Banheiros     2   Vagas',
#   'ende': 'Rua Marechal Hermes da Fonseca, 600 - Santana, São Paulo - SP',
#   'id': '2476266182',
#   'metragem': 93,
#   'nome': 'Apartamento com  Quarto à Venda, 93m²',
#   'preco': 900000},
#  {'amenidades': 'Mobiliado',
#   'desc': '80   m²     2   Quartos     2   Banheiros     --   Vaga',
#   'ende': 'Avenida Nove de Julho, 1050 - Bela Vista, São Paulo - SP',
#   'id': '2476258295',
#   'metragem': 80,
#   'nome': 'Apartamento com 2 Quartos à Venda, 80m²',
#   'preco': 539000},
#  {'amenidades': 'Elevador Salão de festas Jardim Condomínio fechado Escritório',
#   'desc': '97   m²     2   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Itambé, 440 - Higienópolis, São Paulo - SP',
#   'id': '2477014085',
#   'metragem': 97,
#   'nome': 'Apartamento com 2 Quartos à Venda, 97m²',
#   'preco': 980000},
#  {'desc': '290   m²     6   Quartos     5   Banheiros     3   Vagas',
#   'ende': 'Rua Apinajés, 1896 - Sumaré, São Paulo - SP',
#   'id': '2473930912',
#   'metragem': 290,
#   'nome': 'Sobrado com 6 Quartos à Venda, 290m²',
#   'preco': 1590000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '58   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Torres da Barra, 99 - Água Branca, São Paulo - SP',
#   'id': '2495239876',
#   'metragem': 58,
#   'nome': 'Apartamento com 2 Quartos à Venda, 58m²',
#   'preco': 421900},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '58   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Torres da Barra, 99 - Água Branca, São Paulo - SP',
#   'id': '2495229291',
#   'metragem': 58,
#   'nome': 'Apartamento com 2 Quartos à Venda, 58m²',
#   'preco': 403900},
#  {'amenidades': 'Mobiliado Elevador Piscina Área de serviço Churrasqueira ',
#   'desc': '140   m²     3   Quartos     5   Banheiros     2   Vagas',
#   'ende': 'Rua 146, 147 - Setor Marista, Goiânia - GO',
#   'id': '2485814349',
#   'metragem': 140,
#   'nome': 'Apartamento com 3 Quartos à Venda, 140m²',
#   'preco': 699999},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Academia ',
#   'desc': '82   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Buenos Aires, 39 - Jardim das Américas, Cuiabá - MT',
#   'id': '2499704784',
#   'metragem': 82,
#   'nome': 'Apartamento com 3 Quartos à Venda, 82m²',
#   'preco': 390000},
#  {'desc': '48   m²     2   Quartos     1   Banheiro     1   Vaga',
#   'ende': 'Avenida Padre Estanislau de Campos, 87 - Conjunto Habitacional Padre Manoel da Nóbrega, São Paulo - SP',
#   'id': '2501381225',
#   'metragem': 48,
#   'nome': 'Apartamento com 2 Quartos à Venda, 48m²',
#   'preco': 199000},
#  {'amenidades': 'Elevador Piscina Área de serviço Churrasqueira Salão de festas ',
#   'desc': '95   m²     3   Quartos     4   Banheiros     2   Vagas',
#   'ende': 'Rua T 33, 1 - Setor Bueno, Goiânia - GO',
#   'id': '2484719668',
#   'metragem': 95,
#   'nome': 'Apartamento com 3 Quartos à Venda, 95m²',
#   'preco': 539999},
#  {'amenidades': 'Mobiliado Elevador Piscina Academia Ar-condicionado ',
#   'desc': '26   m²     1   Quarto     1   Banheiro     1   Vaga',
#   'ende': 'Avenida Sabiá, , 825 - Indianópolis, São Paulo - SP',
#   'id': '2493994987',
#   'metragem': 26,
#   'nome': 'Flat com  Quarto para Venda/Aluguel 26m²',
#   'preco': 2000},
#  {'amenidades': 'Piscina Área de serviço Churrasqueira Varanda Ar-condicionado ',
#   'desc': '77   m²     3   Quartos     3   Banheiros     2   Vagas',
#   'ende': 'Rua Artur Thiré - Vila da Saúde, São Paulo - SP',
#   'id': '2494214252',
#   'metragem': 77,
#   'nome': 'Apartamento com 3 Quartos à Venda, 77m²',
#   'preco': 680000},
#  {'amenidades': 'Mobiliado Churrasqueira Jardim Ar-condicionado Condomínio fechado ',
#   'desc': '76   m²     3   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Benedito Cardoso Adriano Filho, 100 - Enseada, Guarujá - SP',
#   'id': '2494152308',
#   'metragem': 76,
#   'nome': 'Apartamento com 3 Quartos à Venda, 76m²',
#   'preco': 272000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Ar-condicionado ',
#   'desc': '70   m²     3   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Marivaldo Fernandes, 270 - Enseada, Guarujá - SP',
#   'id': '2474593494',
#   'metragem': 70,
#   'nome': 'Apartamento com 3 Quartos à Venda, 70m²',
#   'preco': 350000},
#  {'desc': '341   m²     4   Quartos     6   Banheiros     4   Vagas',
#   'ende': 'Rua Capitão Alberto Mendes Júnior, 31 - Loteamento Vale Azul I, Jundiaí - SP',
#   'id': '2494336886',
#   'metragem': 341,
#   'nome': 'Casa de condomínio com 4 Quartos à Venda, 341m²',
#   'preco': 1680000},
#  {'amenidades': 'Elevador Churrasqueira Salão de festas Playground Academia ',
#   'desc': '74   m²     3   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Engenheiro Arthur Bettes, 75 - Portão, Curitiba - PR',
#   'id': '2500866017',
#   'metragem': 74,
#   'nome': 'Apartamento com 3 Quartos à Venda, 74m²',
#   'preco': 430000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '64   m²     3   Quartos     1   Banheiro     1   Vaga',
#   'ende': 'Avenida Moinho Fabrini, 385 - Independência, São Bernardo do Campo - SP',
#   'id': '2499614983',
#   'metragem': 64,
#   'nome': 'Apartamento com 3 Quartos à Venda, 64m²',
#   'preco': 405000},
#  {'amenidades': 'Piscina Salão de festas Salão de jogos Aceita animais Salão de jogos ',
#   'desc': '68   m²     2   Quartos     1   Banheiro     1   Vaga',
#   'ende': 'Rua Colômbia, 454 - Guilhermina, Praia Grande - SP',
#   'id': '2501074481',
#   'metragem': 68,
#   'nome': 'Apartamento com 2 Quartos à Venda, 68m²',
#   'preco': 260000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Salão de festas ',
#   'desc': '74   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua dos Jequitibás - Campestre, Santo André - SP',
#   'id': '2500839600',
#   'metragem': 74,
#   'nome': 'Apartamento com 3 Quartos à Venda, 74m²',
#   'preco': 480000},
#  {'amenidades': 'Elevador Piscina Área de serviço Churrasqueira Salão de festas ',
#   'desc': '162   m²     3   Quartos     4   Banheiros     3   Vagas',
#   'ende': 'Avenida José Medeiros Vieira, 1876 - Praia Brava de Itajaí, Itajaí - SC',
#   'id': '2499833175',
#   'metragem': 162,
#   'nome': 'Apartamento com 3 Quartos à Venda, 162m²',
#   'preco': 1740000},
#  {'amenidades': 'Mobiliado Elevador Churrasqueira Salão de festas Playground ',
#   'desc': '55   m²     2   Quartos     1   Banheiro     1   Vaga',
#   'ende': 'Rua Carolina Fonseca, 315 - Vila Santana, São Paulo - SP',
#   'id': '2501209491',
#   'metragem': 55,
#   'nome': 'Apartamento com 2 Quartos à Venda, 55m²',
#   'preco': 220000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '79   m²     3   Quartos     3   Banheiros     1   Vaga',
#   'ende': 'Travessa Magno de Araújo, 370 - Telégrafo Sem Fio, Belém - PA',
#   'id': '2502667901',
#   'metragem': 79,
#   'nome': 'Apartamento com 3 Quartos à Venda, 79m²',
#   'preco': 453960},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '80   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Marte - Jardim Tupanci, Barueri - SP',
#   'id': '2495987482',
#   'metragem': 80,
#   'nome': 'Apartamento com 3 Quartos à Venda, 80m²',
#   'preco': 387000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Salão de festas ',
#   'desc': '90   m²     3   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Mathias Velho, 97 - Centro, Canoas - RS',
#   'id': '2490600476',
#   'metragem': 90,
#   'nome': 'Apartamento com 3 Quartos à Venda, 90m²',
#   'preco': 410000},
#  {'amenidades': 'Varanda',
#   'desc': '83   m²     2   Quartos     3   Banheiros     1   Vaga',
#   'ende': 'Rua Raposo Tavares, 102 - Jardim das Acácias, São Paulo - SP',
#   'id': '2498679480',
#   'metragem': 83,
#   'nome': 'Apartamento com 2 Quartos à Venda, 83m²',
#   'preco': 680000},
#  {'amenidades': 'Elevador Piscina Área de serviço Churrasqueira Salão de festas ',
#   'desc': '120   m²     3   Quartos     4   Banheiros     2   Vagas',
#   'ende': 'Rua 246, 423 - Andorinha, Itapema - SC',
#   'id': '2496574477',
#   'metragem': 120,
#   'nome': 'Apartamento com 3 Quartos à Venda, 120m²',
#   'preco': 719000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '70   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Teixeira Heizer, 1965 - Recreio dos Bandeirantes, Rio de Janeiro - RJ',
#   'id': '2492689561',
#   'metragem': 70,
#   'nome': 'Apartamento com 2 Quartos à Venda, 70m²',
#   'preco': 380000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '101   m²     3   Quartos     3   Banheiros     2   Vagas',
#   'ende': 'Rua Francisco Pessoa, 695 - Vila Andrade, São Paulo - SP',
#   'id': '2476402673',
#   'metragem': 101,
#   'nome': 'Apartamento com 3 Quartos à Venda, 101m²',
#   'preco': 750000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Academia ',
#   'desc': '107   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Paris, 241 - Sumaré, São Paulo - SP',
#   'id': '2473758281',
#   'metragem': 107,
#   'nome': 'Apartamento com 3 Quartos à Venda, 107m²',
#   'preco': 850000},
#  {'amenidades': 'Mobiliado Elevador Piscina Área de serviço Churrasqueira ',
#   'desc': '70   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Cipriano Barata, 790 - Ipiranga, São Paulo - SP',
#   'id': '2475837894',
#   'metragem': 70,
#   'nome': 'Apartamento com 2 Quartos à Venda, 70m²',
#   'preco': 565000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Salão de festas ',
#   'desc': '57   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Cônego Vicente Miguel Marino, 183 - Barra Funda, São Paulo - SP',
#   'id': '2476743581',
#   'metragem': 57,
#   'nome': 'Apartamento com 2 Quartos à Venda, 57m²',
#   'preco': 490000},
#  {'amenidades': 'Elevador Academia Condomínio fechado',
#   'desc': '290   m²     6   Quartos     5   Banheiros     2   Vagas',
#   'ende': 'Alameda Tietê, 325 - Jardim Paulista, São Paulo - SP',
#   'id': '2477112488',
#   'metragem': 290,
#   'nome': 'Apartamento com 6 Quartos à Venda, 290m²',
#   'preco': 3000000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Salão de festas ',
#   'desc': '48   m²     1   Quarto     2   Banheiros     1   Vaga',
#   'ende': 'Rua Major Quedinho, 224 - Centro, São Paulo - SP',
#   'id': '2476286177',
#   'metragem': 48,
#   'nome': 'Apartamento com  Quarto à Venda, 48m²',
#   'preco': 600000},
#  {'amenidades': 'Elevador Piscina Área de serviço Churrasqueira Salão de festas ',
#   'desc': '93   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Cônego Vicente Miguel Marino, 175 - Barra Funda, São Paulo - SP',
#   'id': '2476274799',
#   'metragem': 93,
#   'nome': 'Apartamento com 3 Quartos à Venda, 93m²',
#   'preco': 600000},
#  {'amenidades': 'Elevador Piscina Salão de festas Playground Academia ',
#   'desc': '160   m²     3   Quartos     3   Banheiros     2   Vagas',
#   'ende': 'Rua André Dreyfus, 109 - Sumaré, São Paulo - SP',
#   'id': '2473759712',
#   'metragem': 160,
#   'nome': 'Apartamento com 3 Quartos à Venda, 160m²',
#   'preco': 1300000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '84   m²     1   Quarto     2   Banheiros     1   Vaga',
#   'ende': 'Rua Turiassu, 507 - Perdizes, São Paulo - SP',
#   'id': '2476277377',
#   'metragem': 84,
#   'nome': 'Apartamento com  Quarto à Venda, 84m²',
#   'preco': 1060000},
#  {'amenidades': 'Churrasqueira Salão de festas Playground Academia Sauna ',
#   'desc': '93   m²     1   Quarto     2   Banheiros     2   Vagas',
#   'ende': 'Rua Marechal Hermes da Fonseca, 600 - Santana, São Paulo - SP',
#   'id': '2476266182',
#   'metragem': 93,
#   'nome': 'Apartamento com  Quarto à Venda, 93m²',
#   'preco': 900000},
#  {'amenidades': 'Mobiliado',
#   'desc': '80   m²     2   Quartos     2   Banheiros     --   Vaga',
#   'ende': 'Avenida Nove de Julho, 1050 - Bela Vista, São Paulo - SP',
#   'id': '2476258295',
#   'metragem': 80,
#   'nome': 'Apartamento com 2 Quartos à Venda, 80m²',
#   'preco': 539000},
#  {'amenidades': 'Elevador Salão de festas Jardim Condomínio fechado Escritório',
#   'desc': '97   m²     2   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Itambé, 440 - Higienópolis, São Paulo - SP',
#   'id': '2477014085',
#   'metragem': 97,
#   'nome': 'Apartamento com 2 Quartos à Venda, 97m²',
#   'preco': 980000},
#  {'desc': '290   m²     6   Quartos     5   Banheiros     3   Vagas',
#   'ende': 'Rua Apinajés, 1896 - Sumaré, São Paulo - SP',
#   'id': '2473930912',
#   'metragem': 290,
#   'nome': 'Sobrado com 6 Quartos à Venda, 290m²',
#   'preco': 1590000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '58   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Torres da Barra, 99 - Água Branca, São Paulo - SP',
#   'id': '2495239876',
#   'metragem': 58,
#   'nome': 'Apartamento com 2 Quartos à Venda, 58m²',
#   'preco': 421900},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '58   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Torres da Barra, 99 - Água Branca, São Paulo - SP',
#   'id': '2495229291',
#   'metragem': 58,
#   'nome': 'Apartamento com 2 Quartos à Venda, 58m²',
#   'preco': 403900},
#  {'amenidades': 'Mobiliado Elevador Piscina Área de serviço Churrasqueira ',
#   'desc': '140   m²     3   Quartos     5   Banheiros     2   Vagas',
#   'ende': 'Rua 146, 147 - Setor Marista, Goiânia - GO',
#   'id': '2485814349',
#   'metragem': 140,
#   'nome': 'Apartamento com 3 Quartos à Venda, 140m²',
#   'preco': 699999},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Academia ',
#   'desc': '82   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Buenos Aires, 39 - Jardim das Américas, Cuiabá - MT',
#   'id': '2499704784',
#   'metragem': 82,
#   'nome': 'Apartamento com 3 Quartos à Venda, 82m²',
#   'preco': 390000},
#  {'desc': '48   m²     2   Quartos     1   Banheiro     1   Vaga',
#   'ende': 'Avenida Padre Estanislau de Campos, 87 - Conjunto Habitacional Padre Manoel da Nóbrega, São Paulo - SP',
#   'id': '2501381225',
#   'metragem': 48,
#   'nome': 'Apartamento com 2 Quartos à Venda, 48m²',
#   'preco': 199000},
#  {'amenidades': 'Elevador Piscina Área de serviço Churrasqueira Salão de festas ',
#   'desc': '95   m²     3   Quartos     4   Banheiros     2   Vagas',
#   'ende': 'Rua T 33, 1 - Setor Bueno, Goiânia - GO',
#   'id': '2484719668',
#   'metragem': 95,
#   'nome': 'Apartamento com 3 Quartos à Venda, 95m²',
#   'preco': 539999},
#  {'amenidades': 'Mobiliado Elevador Piscina Academia Ar-condicionado ',
#   'desc': '26   m²     1   Quarto     1   Banheiro     1   Vaga',
#   'ende': 'Avenida Sabiá, , 825 - Indianópolis, São Paulo - SP',
#   'id': '2493994987',
#   'metragem': 26,
#   'nome': 'Flat com  Quarto para Venda/Aluguel 26m²',
#   'preco': 2000},
#  {'amenidades': 'Piscina Área de serviço Churrasqueira Varanda Ar-condicionado ',
#   'desc': '77   m²     3   Quartos     3   Banheiros     2   Vagas',
#   'ende': 'Rua Artur Thiré - Vila da Saúde, São Paulo - SP',
#   'id': '2494214252',
#   'metragem': 77,
#   'nome': 'Apartamento com 3 Quartos à Venda, 77m²',
#   'preco': 680000},
#  {'amenidades': 'Mobiliado Churrasqueira Jardim Ar-condicionado Condomínio fechado ',
#   'desc': '76   m²     3   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Benedito Cardoso Adriano Filho, 100 - Enseada, Guarujá - SP',
#   'id': '2494152308',
#   'metragem': 76,
#   'nome': 'Apartamento com 3 Quartos à Venda, 76m²',
#   'preco': 272000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Ar-condicionado ',
#   'desc': '70   m²     3   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Marivaldo Fernandes, 270 - Enseada, Guarujá - SP',
#   'id': '2474593494',
#   'metragem': 70,
#   'nome': 'Apartamento com 3 Quartos à Venda, 70m²',
#   'preco': 350000},
#  {'desc': '341   m²     4   Quartos     6   Banheiros     4   Vagas',
#   'ende': 'Rua Capitão Alberto Mendes Júnior, 31 - Loteamento Vale Azul I, Jundiaí - SP',
#   'id': '2494336886',
#   'metragem': 341,
#   'nome': 'Casa de condomínio com 4 Quartos à Venda, 341m²',
#   'preco': 1680000},
#  {'amenidades': 'Elevador Churrasqueira Salão de festas Playground Academia ',
#   'desc': '74   m²     3   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Engenheiro Arthur Bettes, 75 - Portão, Curitiba - PR',
#   'id': '2500866017',
#   'metragem': 74,
#   'nome': 'Apartamento com 3 Quartos à Venda, 74m²',
#   'preco': 430000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '64   m²     3   Quartos     1   Banheiro     1   Vaga',
#   'ende': 'Avenida Moinho Fabrini, 385 - Independência, São Bernardo do Campo - SP',
#   'id': '2499614983',
#   'metragem': 64,
#   'nome': 'Apartamento com 3 Quartos à Venda, 64m²',
#   'preco': 405000},
#  {'amenidades': 'Piscina Salão de festas Salão de jogos Aceita animais Salão de jogos ',
#   'desc': '68   m²     2   Quartos     1   Banheiro     1   Vaga',
#   'ende': 'Rua Colômbia, 454 - Guilhermina, Praia Grande - SP',
#   'id': '2501074481',
#   'metragem': 68,
#   'nome': 'Apartamento com 2 Quartos à Venda, 68m²',
#   'preco': 260000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Salão de festas ',
#   'desc': '74   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua dos Jequitibás - Campestre, Santo André - SP',
#   'id': '2500839600',
#   'metragem': 74,
#   'nome': 'Apartamento com 3 Quartos à Venda, 74m²',
#   'preco': 480000},
#  {'amenidades': 'Elevador Piscina Área de serviço Churrasqueira Salão de festas ',
#   'desc': '162   m²     3   Quartos     4   Banheiros     3   Vagas',
#   'ende': 'Avenida José Medeiros Vieira, 1876 - Praia Brava de Itajaí, Itajaí - SC',
#   'id': '2499833175',
#   'metragem': 162,
#   'nome': 'Apartamento com 3 Quartos à Venda, 162m²',
#   'preco': 1740000},
#  {'amenidades': 'Mobiliado Elevador Churrasqueira Salão de festas Playground ',
#   'desc': '55   m²     2   Quartos     1   Banheiro     1   Vaga',
#   'ende': 'Rua Carolina Fonseca, 315 - Vila Santana, São Paulo - SP',
#   'id': '2501209491',
#   'metragem': 55,
#   'nome': 'Apartamento com 2 Quartos à Venda, 55m²',
#   'preco': 220000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '79   m²     3   Quartos     3   Banheiros     1   Vaga',
#   'ende': 'Travessa Magno de Araújo, 370 - Telégrafo Sem Fio, Belém - PA',
#   'id': '2502667901',
#   'metragem': 79,
#   'nome': 'Apartamento com 3 Quartos à Venda, 79m²',
#   'preco': 453960},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '80   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Marte - Jardim Tupanci, Barueri - SP',
#   'id': '2495987482',
#   'metragem': 80,
#   'nome': 'Apartamento com 3 Quartos à Venda, 80m²',
#   'preco': 387000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Salão de festas ',
#   'desc': '90   m²     3   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Mathias Velho, 97 - Centro, Canoas - RS',
#   'id': '2490600476',
#   'metragem': 90,
#   'nome': 'Apartamento com 3 Quartos à Venda, 90m²',
#   'preco': 410000},
#  {'amenidades': 'Varanda',
#   'desc': '83   m²     2   Quartos     3   Banheiros     1   Vaga',
#   'ende': 'Rua Raposo Tavares, 102 - Jardim das Acácias, São Paulo - SP',
#   'id': '2498679480',
#   'metragem': 83,
#   'nome': 'Apartamento com 2 Quartos à Venda, 83m²',
#   'preco': 680000},
#  {'amenidades': 'Elevador Piscina Área de serviço Churrasqueira Salão de festas ',
#   'desc': '120   m²     3   Quartos     4   Banheiros     2   Vagas',
#   'ende': 'Rua 246, 423 - Andorinha, Itapema - SC',
#   'id': '2496574477',
#   'metragem': 120,
#   'nome': 'Apartamento com 3 Quartos à Venda, 120m²',
#   'preco': 719000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '70   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Teixeira Heizer, 1965 - Recreio dos Bandeirantes, Rio de Janeiro - RJ',
#   'id': '2492689561',
#   'metragem': 70,
#   'nome': 'Apartamento com 2 Quartos à Venda, 70m²',
#   'preco': 380000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '101   m²     3   Quartos     3   Banheiros     2   Vagas',
#   'ende': 'Rua Francisco Pessoa, 695 - Vila Andrade, São Paulo - SP',
#   'id': '2476402673',
#   'metragem': 101,
#   'nome': 'Apartamento com 3 Quartos à Venda, 101m²',
#   'preco': 750000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Academia ',
#   'desc': '107   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Paris, 241 - Sumaré, São Paulo - SP',
#   'id': '2473758281',
#   'metragem': 107,
#   'nome': 'Apartamento com 3 Quartos à Venda, 107m²',
#   'preco': 850000},
#  {'amenidades': 'Mobiliado Elevador Piscina Área de serviço Churrasqueira ',
#   'desc': '70   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Cipriano Barata, 790 - Ipiranga, São Paulo - SP',
#   'id': '2475837894',
#   'metragem': 70,
#   'nome': 'Apartamento com 2 Quartos à Venda, 70m²',
#   'preco': 565000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Salão de festas ',
#   'desc': '57   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Cônego Vicente Miguel Marino, 183 - Barra Funda, São Paulo - SP',
#   'id': '2476743581',
#   'metragem': 57,
#   'nome': 'Apartamento com 2 Quartos à Venda, 57m²',
#   'preco': 490000},
#  {'amenidades': 'Elevador Academia Condomínio fechado',
#   'desc': '290   m²     6   Quartos     5   Banheiros     2   Vagas',
#   'ende': 'Alameda Tietê, 325 - Jardim Paulista, São Paulo - SP',
#   'id': '2477112488',
#   'metragem': 290,
#   'nome': 'Apartamento com 6 Quartos à Venda, 290m²',
#   'preco': 3000000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Salão de festas ',
#   'desc': '48   m²     1   Quarto     2   Banheiros     1   Vaga',
#   'ende': 'Rua Major Quedinho, 224 - Centro, São Paulo - SP',
#   'id': '2476286177',
#   'metragem': 48,
#   'nome': 'Apartamento com  Quarto à Venda, 48m²',
#   'preco': 600000},
# ...
#   'desc': '70   m²     3   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Marivaldo Fernandes, 270 - Enseada, Guarujá - SP',
#   'id': '2474593494',
#   'metragem': 70,
#   'nome': 'Apartamento com 3 Quartos à Venda, 70m²',
#   'preco': 350000},
#  {'desc': '341   m²     4   Quartos     6   Banheiros     4   Vagas',
#   'ende': 'Rua Capitão Alberto Mendes Júnior, 31 - Loteamento Vale Azul I, Jundiaí - SP',
#   'id': '2494336886',
#   'metragem': 341,
#   'nome': 'Casa de condomínio com 4 Quartos à Venda, 341m²',
#   'preco': 1680000},
#  {'amenidades': 'Elevador Churrasqueira Salão de festas Playground Academia ',
#   'desc': '74   m²     3   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Engenheiro Arthur Bettes, 75 - Portão, Curitiba - PR',
#   'id': '2500866017',
#   'metragem': 74,
#   'nome': 'Apartamento com 3 Quartos à Venda, 74m²',
#   'preco': 430000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '64   m²     3   Quartos     1   Banheiro     1   Vaga',
#   'ende': 'Avenida Moinho Fabrini, 385 - Independência, São Bernardo do Campo - SP',
#   'id': '2499614983',
#   'metragem': 64,
#   'nome': 'Apartamento com 3 Quartos à Venda, 64m²',
#   'preco': 405000},
#  {'amenidades': 'Piscina Salão de festas Salão de jogos Aceita animais Salão de jogos ',
#   'desc': '68   m²     2   Quartos     1   Banheiro     1   Vaga',
#   'ende': 'Rua Colômbia, 454 - Guilhermina, Praia Grande - SP',
#   'id': '2501074481',
#   'metragem': 68,
#   'nome': 'Apartamento com 2 Quartos à Venda, 68m²',
#   'preco': 260000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Salão de festas ',
#   'desc': '74   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua dos Jequitibás - Campestre, Santo André - SP',
#   'id': '2500839600',
#   'metragem': 74,
#   'nome': 'Apartamento com 3 Quartos à Venda, 74m²',
#   'preco': 480000},
#  {'amenidades': 'Elevador Piscina Área de serviço Churrasqueira Salão de festas ',
#   'desc': '162   m²     3   Quartos     4   Banheiros     3   Vagas',
#   'ende': 'Avenida José Medeiros Vieira, 1876 - Praia Brava de Itajaí, Itajaí - SC',
#   'id': '2499833175',
#   'metragem': 162,
#   'nome': 'Apartamento com 3 Quartos à Venda, 162m²',
#   'preco': 1740000},
#  {'amenidades': 'Mobiliado Elevador Churrasqueira Salão de festas Playground ',
#   'desc': '55   m²     2   Quartos     1   Banheiro     1   Vaga',
#   'ende': 'Rua Carolina Fonseca, 315 - Vila Santana, São Paulo - SP',
#   'id': '2501209491',
#   'metragem': 55,
#   'nome': 'Apartamento com 2 Quartos à Venda, 55m²',
#   'preco': 220000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '79   m²     3   Quartos     3   Banheiros     1   Vaga',
#   'ende': 'Travessa Magno de Araújo, 370 - Telégrafo Sem Fio, Belém - PA',
#   'id': '2502667901',
#   'metragem': 79,
#   'nome': 'Apartamento com 3 Quartos à Venda, 79m²',
#   'preco': 453960},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '80   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Marte - Jardim Tupanci, Barueri - SP',
#   'id': '2495987482',
#   'metragem': 80,
#   'nome': 'Apartamento com 3 Quartos à Venda, 80m²',
#   'preco': 387000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Salão de festas ',
#   'desc': '90   m²     3   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Mathias Velho, 97 - Centro, Canoas - RS',
#   'id': '2490600476',
#   'metragem': 90,
#   'nome': 'Apartamento com 3 Quartos à Venda, 90m²',
#   'preco': 410000},
#  {'amenidades': 'Varanda',
#   'desc': '83   m²     2   Quartos     3   Banheiros     1   Vaga',
#   'ende': 'Rua Raposo Tavares, 102 - Jardim das Acácias, São Paulo - SP',
#   'id': '2498679480',
#   'metragem': 83,
#   'nome': 'Apartamento com 2 Quartos à Venda, 83m²',
#   'preco': 680000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '62   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Godofredo Fraga, 10 - Marapé, Santos - SP',
#   'id': '2501376484',
#   'metragem': 62,
#   'nome': 'Apartamento com 2 Quartos à Venda, 62m²',
#   'preco': 367000},
#  {'amenidades': 'Elevador Piscina Área de serviço Churrasqueira Salão de festas ',
#   'desc': '120   m²     3   Quartos     4   Banheiros     2   Vagas',
#   'ende': 'Rua 246, 423 - Andorinha, Itapema - SC',
#   'id': '2496574477',
#   'metragem': 120,
#   'nome': 'Apartamento com 3 Quartos à Venda, 120m²',
#   'preco': 719000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '101   m²     3   Quartos     3   Banheiros     2   Vagas',
#   'ende': 'Rua Francisco Pessoa, 695 - Vila Andrade, São Paulo - SP',
#   'id': '2476402673',
#   'metragem': 101,
#   'nome': 'Apartamento com 3 Quartos à Venda, 101m²',
#   'preco': 750000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Academia ',
#   'desc': '107   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Paris, 241 - Sumaré, São Paulo - SP',
#   'id': '2473758281',
#   'metragem': 107,
#   'nome': 'Apartamento com 3 Quartos à Venda, 107m²',
#   'preco': 850000},
#  {'amenidades': 'Mobiliado Elevador Piscina Área de serviço Churrasqueira ',
#   'desc': '70   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Cipriano Barata, 790 - Ipiranga, São Paulo - SP',
#   'id': '2475837894',
#   'metragem': 70,
#   'nome': 'Apartamento com 2 Quartos à Venda, 70m²',
#   'preco': 565000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Salão de festas ',
#   'desc': '57   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Cônego Vicente Miguel Marino, 183 - Barra Funda, São Paulo - SP',
#   'id': '2476743581',
#   'metragem': 57,
#   'nome': 'Apartamento com 2 Quartos à Venda, 57m²',
#   'preco': 490000},
#  {'amenidades': 'Elevador Academia Condomínio fechado',
#   'desc': '290   m²     6   Quartos     5   Banheiros     2   Vagas',
#   'ende': 'Alameda Tietê, 325 - Jardim Paulista, São Paulo - SP',
#   'id': '2477112488',
#   'metragem': 290,
#   'nome': 'Apartamento com 6 Quartos à Venda, 290m²',
#   'preco': 3000000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Salão de festas ',
#   'desc': '48   m²     1   Quarto     2   Banheiros     1   Vaga',
#   'ende': 'Rua Major Quedinho, 224 - Centro, São Paulo - SP',
#   'id': '2476286177',
#   'metragem': 48,
#   'nome': 'Apartamento com  Quarto à Venda, 48m²',
#   'preco': 600000},
#  {'amenidades': 'Elevador Piscina Área de serviço Churrasqueira Salão de festas ',
#   'desc': '93   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Cônego Vicente Miguel Marino, 175 - Barra Funda, São Paulo - SP',
#   'id': '2476274799',
#   'metragem': 93,
#   'nome': 'Apartamento com 3 Quartos à Venda, 93m²',
#   'preco': 600000},
#  {'amenidades': 'Elevador Piscina Salão de festas Playground Academia ',
#   'desc': '160   m²     3   Quartos     3   Banheiros     2   Vagas',
#   'ende': 'Rua André Dreyfus, 109 - Sumaré, São Paulo - SP',
#   'id': '2473759712',
#   'metragem': 160,
#   'nome': 'Apartamento com 3 Quartos à Venda, 160m²',
#   'preco': 1300000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '84   m²     1   Quarto     2   Banheiros     1   Vaga',
#   'ende': 'Rua Turiassu, 507 - Perdizes, São Paulo - SP',
#   'id': '2476277377',
#   'metragem': 84,
#   'nome': 'Apartamento com  Quarto à Venda, 84m²',
#   'preco': 1060000},
#  {'amenidades': 'Churrasqueira Salão de festas Playground Academia Sauna ',
#   'desc': '93   m²     1   Quarto     2   Banheiros     2   Vagas',
#   'ende': 'Rua Marechal Hermes da Fonseca, 600 - Santana, São Paulo - SP',
#   'id': '2476266182',
#   'metragem': 93,
#   'nome': 'Apartamento com  Quarto à Venda, 93m²',
#   'preco': 900000},
#  {'amenidades': 'Mobiliado',
#   'desc': '80   m²     2   Quartos     2   Banheiros     --   Vaga',
#   'ende': 'Avenida Nove de Julho, 1050 - Bela Vista, São Paulo - SP',
#   'id': '2476258295',
#   'metragem': 80,
#   'nome': 'Apartamento com 2 Quartos à Venda, 80m²',
#   'preco': 539000},
#  {'amenidades': 'Elevador Salão de festas Jardim Condomínio fechado Escritório',
#   'desc': '97   m²     2   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Itambé, 440 - Higienópolis, São Paulo - SP',
#   'id': '2477014085',
#   'metragem': 97,
#   'nome': 'Apartamento com 2 Quartos à Venda, 97m²',
#   'preco': 980000},
#  {'desc': '290   m²     6   Quartos     5   Banheiros     3   Vagas',
#   'ende': 'Rua Apinajés, 1896 - Sumaré, São Paulo - SP',
#   'id': '2473930912',
#   'metragem': 290,
#   'nome': 'Sobrado com 6 Quartos à Venda, 290m²',
#   'preco': 1590000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '58   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Torres da Barra, 99 - Água Branca, São Paulo - SP',
#   'id': '2495239876',
#   'metragem': 58,
#   'nome': 'Apartamento com 2 Quartos à Venda, 58m²',
#   'preco': 421900},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '58   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Torres da Barra, 99 - Água Branca, São Paulo - SP',
#   'id': '2495229291',
#   'metragem': 58,
#   'nome': 'Apartamento com 2 Quartos à Venda, 58m²',
#   'preco': 403900},
#  {'amenidades': 'Mobiliado Elevador Piscina Área de serviço Churrasqueira ',
#   'desc': '140   m²     3   Quartos     5   Banheiros     2   Vagas',
#   'ende': 'Rua 146, 147 - Setor Marista, Goiânia - GO',
#   'id': '2485814349',
#   'metragem': 140,
#   'nome': 'Apartamento com 3 Quartos à Venda, 140m²',
#   'preco': 699999},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Academia ',
#   'desc': '82   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Buenos Aires, 39 - Jardim das Américas, Cuiabá - MT',
#   'id': '2499704784',
#   'metragem': 82,
#   'nome': 'Apartamento com 3 Quartos à Venda, 82m²',
#   'preco': 390000},
#  {'desc': '48   m²     2   Quartos     1   Banheiro     1   Vaga',
#   'ende': 'Avenida Padre Estanislau de Campos, 87 - Conjunto Habitacional Padre Manoel da Nóbrega, São Paulo - SP',
#   'id': '2501381225',
#   'metragem': 48,
#   'nome': 'Apartamento com 2 Quartos à Venda, 48m²',
#   'preco': 199000},
#  {'amenidades': 'Elevador Piscina Área de serviço Churrasqueira Salão de festas ',
#   'desc': '95   m²     3   Quartos     4   Banheiros     2   Vagas',
#   'ende': 'Rua T 33, 1 - Setor Bueno, Goiânia - GO',
#   'id': '2484719668',
#   'metragem': 95,
#   'nome': 'Apartamento com 3 Quartos à Venda, 95m²',
#   'preco': 539999},
#  {'amenidades': 'Mobiliado Elevador Piscina Academia Ar-condicionado ',
#   'desc': '26   m²     1   Quarto     1   Banheiro     1   Vaga',
#   'ende': 'Avenida Sabiá, , 825 - Indianópolis, São Paulo - SP',
#   'id': '2493994987',
#   'metragem': 26,
#   'nome': 'Flat com  Quarto para Venda/Aluguel 26m²',
#   'preco': 2000},
#  {'amenidades': 'Piscina Área de serviço Churrasqueira Varanda Ar-condicionado ',
#   'desc': '77   m²     3   Quartos     3   Banheiros     2   Vagas',
#   'ende': 'Rua Artur Thiré - Vila da Saúde, São Paulo - SP',
#   'id': '2494214252',
#   'metragem': 77,
#   'nome': 'Apartamento com 3 Quartos à Venda, 77m²',
#   'preco': 680000},
#  {'amenidades': 'Mobiliado Churrasqueira Jardim Ar-condicionado Condomínio fechado ',
#   'desc': '76   m²     3   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Benedito Cardoso Adriano Filho, 100 - Enseada, Guarujá - SP',
#   'id': '2494152308',
#   'metragem': 76,
#   'nome': 'Apartamento com 3 Quartos à Venda, 76m²',
#   'preco': 272000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Ar-condicionado ',
#   'desc': '70   m²     3   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Marivaldo Fernandes, 270 - Enseada, Guarujá - SP',
#   'id': '2474593494',
#   'metragem': 70,
#   'nome': 'Apartamento com 3 Quartos à Venda, 70m²',
#   'preco': 350000},
#  {'desc': '341   m²     4   Quartos     6   Banheiros     4   Vagas',
#   'ende': 'Rua Capitão Alberto Mendes Júnior, 31 - Loteamento Vale Azul I, Jundiaí - SP',
#   'id': '2494336886',
#   'metragem': 341,
#   'nome': 'Casa de condomínio com 4 Quartos à Venda, 341m²',
#   'preco': 1680000},
#  {'amenidades': 'Elevador Churrasqueira Salão de festas Playground Academia ',
#   'desc': '74   m²     3   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Engenheiro Arthur Bettes, 75 - Portão, Curitiba - PR',
#   'id': '2500866017',
#   'metragem': 74,
#   'nome': 'Apartamento com 3 Quartos à Venda, 74m²',
#   'preco': 430000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '64   m²     3   Quartos     1   Banheiro     1   Vaga',
#   'ende': 'Avenida Moinho Fabrini, 385 - Independência, São Bernardo do Campo - SP',
#   'id': '2499614983',
#   'metragem': 64,
#   'nome': 'Apartamento com 3 Quartos à Venda, 64m²',
#   'preco': 405000},
#  {'amenidades': 'Piscina Salão de festas Salão de jogos Aceita animais Salão de jogos ',
#   'desc': '68   m²     2   Quartos     1   Banheiro     1   Vaga',
#   'ende': 'Rua Colômbia, 454 - Guilhermina, Praia Grande - SP',
#   'id': '2501074481',
#   'metragem': 68,
#   'nome': 'Apartamento com 2 Quartos à Venda, 68m²',
#   'preco': 260000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Salão de festas ',
#   'desc': '74   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua dos Jequitibás - Campestre, Santo André - SP',
#   'id': '2500839600',
#   'metragem': 74,
#   'nome': 'Apartamento com 3 Quartos à Venda, 74m²',
#   'preco': 480000},
#  {'amenidades': 'Elevador Piscina Área de serviço Churrasqueira Salão de festas ',
#   'desc': '162   m²     3   Quartos     4   Banheiros     3   Vagas',
#   'ende': 'Avenida José Medeiros Vieira, 1876 - Praia Brava de Itajaí, Itajaí - SC',
#   'id': '2499833175',
#   'metragem': 162,
#   'nome': 'Apartamento com 3 Quartos à Venda, 162m²',
#   'preco': 1740000},
#  {'amenidades': 'Mobiliado Elevador Churrasqueira Salão de festas Playground ',
#   'desc': '55   m²     2   Quartos     1   Banheiro     1   Vaga',
#   'ende': 'Rua Carolina Fonseca, 315 - Vila Santana, São Paulo - SP',
#   'id': '2501209491',
#   'metragem': 55,
#   'nome': 'Apartamento com 2 Quartos à Venda, 55m²',
#   'preco': 220000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '79   m²     3   Quartos     3   Banheiros     1   Vaga',
#   'ende': 'Travessa Magno de Araújo, 370 - Telégrafo Sem Fio, Belém - PA',
#   'id': '2502667901',
#   'metragem': 79,
#   'nome': 'Apartamento com 3 Quartos à Venda, 79m²',
#   'preco': 453960},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '80   m²     3   Quartos     2   Banheiros     2   Vagas',
#   'ende': 'Rua Marte - Jardim Tupanci, Barueri - SP',
#   'id': '2495987482',
#   'metragem': 80,
#   'nome': 'Apartamento com 3 Quartos à Venda, 80m²',
#   'preco': 387000},
#  {'amenidades': 'Mobiliado Elevador Piscina Churrasqueira Salão de festas ',
#   'desc': '90   m²     3   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Mathias Velho, 97 - Centro, Canoas - RS',
#   'id': '2490600476',
#   'metragem': 90,
#   'nome': 'Apartamento com 3 Quartos à Venda, 90m²',
#   'preco': 410000},
#  {'amenidades': 'Varanda',
#   'desc': '83   m²     2   Quartos     3   Banheiros     1   Vaga',
#   'ende': 'Rua Raposo Tavares, 102 - Jardim das Acácias, São Paulo - SP',
#   'id': '2498679480',
#   'metragem': 83,
#   'nome': 'Apartamento com 2 Quartos à Venda, 83m²',
#   'preco': 680000},
#  {'amenidades': 'Elevador Piscina Área de serviço Churrasqueira Salão de festas ',
#   'desc': '120   m²     3   Quartos     4   Banheiros     2   Vagas',
#   'ende': 'Rua 246, 423 - Andorinha, Itapema - SC',
#   'id': '2496574477',
#   'metragem': 120,
#   'nome': 'Apartamento com 3 Quartos à Venda, 120m²',
#   'preco': 719000},
#  {'amenidades': 'Elevador Piscina Churrasqueira Salão de festas Playground ',
#   'desc': '70   m²     2   Quartos     2   Banheiros     1   Vaga',
#   'ende': 'Rua Teixeira Heizer, 1965 - Recreio dos Bandeirantes, Rio de Janeiro - RJ',
#   'id': '2492689561',
#   'metragem': 70,
#   'nome': 'Apartamento com 2 Quartos à Venda, 70m²',
#   'preco': 380000}]

# %% [markdown]
# Agora converterei minha lista de dicts para um DataFrame chamado `todosOsImoveis`. Para tal, crio um DataFrame vazio nomeando as colunas com as chaves de um dict `uni`.

# %%
# Crio um DataFrame vazio cujas colunas são as chaves de 1 unidade:
todosOsImoveis=pd.DataFrame(columns=uni.keys())
todosOsImoveis
# Out:
# Empty DataFrame
# Columns: [id, nome, ende, metragem, preco, desc, amenidades]
# Index: []

# %% [markdown]
# Com o esqueleto do DataFrame pronto, adiciono nele todos os meus dicts (imóveis).

# %%
todosOsImoveis=todosOsImoveis.append(imóveis)

todosOsImoveis.head()
# Out:
#            id  ...                                         amenidades
# 0  2476402673  ...  Elevador Piscina Churrasqueira Salão de festas...
# 1  2473758281  ...  Elevador Piscina Churrasqueira Salão de festas...
# 2  2475837894  ...  Mobiliado Elevador Piscina Área de serviço Chu...
# 3  2476743581  ...  Mobiliado Elevador Piscina Churrasqueira Salão...
# 4  2477112488  ...               Elevador Academia Condomínio fechado
#
# [5 rows x 7 columns]

# %% [markdown]
# Agora em Pandas, vamos dar uma otimizadinha básica convertendo algumas colunas textuais para tipos numéricos.

# %%
todosOsImoveis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 720 entries, 0 to 719
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          720 non-null    object
#  1   nome        720 non-null    object
#  2   ende        720 non-null    object
#  3   metragem    720 non-null    object
#  4   preco       720 non-null    object
#  5   desc        720 non-null    object
#  6   amenidades  660 non-null    object
# dtypes: object(7)
# memory usage: 45.0+ KB

# %% [markdown]
# Como ficaram os tipos de nossas colunas...

# %%
todosOsImoveis=todosOsImoveis.convert_dtypes()

# %%
todosOsImoveis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 720 entries, 0 to 719
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          720 non-null    string
#  1   nome        720 non-null    string
#  2   ende        720 non-null    string
#  3   metragem    720 non-null    Int64
#  4   preco       720 non-null    Int64
#  5   desc        720 non-null    string
#  6   amenidades  660 non-null    string
# dtypes: Int64(2), string(5)
# memory usage: 46.4 KB

# %% [markdown]
# Por que a coluna `id` não foi convertida para `Int64` como as outras? Vamos forçar:

# %%
todosOsImoveis['id']=pd.to_numeric(todosOsImoveis['id'])

# %%
todosOsImoveis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 720 entries, 0 to 719
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          720 non-null    int64
#  1   nome        720 non-null    string
#  2   ende        720 non-null    string
#  3   metragem    720 non-null    Int64
#  4   preco       720 non-null    Int64
#  5   desc        720 non-null    string
#  6   amenidades  660 non-null    string
# dtypes: Int64(2), int64(1), string(4)
# memory usage: 46.4 KB

# %% [markdown]
# Seta o índice para o ID do imóvel

# %%
todosOsImoveis.set_index(keys='id', inplace=True)

# %% [markdown]
# Eis o nosso DataFrame pronto:

# %%
todosOsImoveis.head()
# Out:
#                                                 nome  ...                                         amenidades
# id                                                    ...
# 2476402673  Apartamento com 3 Quartos à Venda, 101m²  ...  Elevador Piscina Churrasqueira Salão de festas...
# 2473758281  Apartamento com 3 Quartos à Venda, 107m²  ...  Elevador Piscina Churrasqueira Salão de festas...
# 2475837894   Apartamento com 2 Quartos à Venda, 70m²  ...  Mobiliado Elevador Piscina Área de serviço Chu...
# 2476743581   Apartamento com 2 Quartos à Venda, 57m²  ...  Mobiliado Elevador Piscina Churrasqueira Salão...
# 2477112488  Apartamento com 6 Quartos à Venda, 290m²  ...               Elevador Academia Condomínio fechado
#
# [5 rows x 6 columns]

# %% [markdown]
# ##Removendo valores duplicados

# %% [markdown]
# No momento em que estou rodando esse código temos 683 valores duplicados, isto é, imóveis repetidos.

# %%
todosOsImoveis.duplicated().sum()
# Out:
# 683

# %% [markdown]
# Vamos cortar esses valores do dataframe antes de inseri-los em um banco de dados sqlite

# %%
todosOsImoveis.drop_duplicates(inplace= True)

# %% [markdown]
# Conferindo se foram retirados

# %%
todosOsImoveis.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Grava o DataFrame inteiro num Banco de Dados
#
# Este é o código para abrir ou criar um aquivo SQLite chamado `VivaReal.db`, na tabela `venda`. Para usar outro banco, como MariaDB, Oracle, DB2, altere esta célula e use a biblioteca SQL Alchemy com os drivers corretos. Todo o resto do código funcionará igual.

# %%
dbfile = 'VivaReal.db'
tabela = 'venda'

db = sqlite3.connect(dbfile)

# %% [markdown]
# Determina os tipos de cada coluna SQL baseado nos tipos das colunas Pandas:

# %%
sqlDataTypes={}

for c in todosOsImoveis.columns:
    if todosOsImoveis[c].dtype.kind == 'i':
        sqlDataTypes[c]='INTEGER'
    elif todosOsImoveis[c].dtype.kind == 'f':
        sqlDataTypes[c]='REAL'
    else:
        sqlDataTypes[c]='TEXT'

sqlDataTypes
# Out:
# {'amenidades': 'TEXT',
#  'desc': 'TEXT',
#  'ende': 'TEXT',
#  'metragem': 'INTEGER',
#  'nome': 'TEXT',
#  'preco': 'INTEGER'}

# %% [markdown]
# Escreve na tabela

# %%
todosOsImoveis.to_sql(tabela, index=True, if_exists='replace', dtype=sqlDataTypes, con=db)

# %% [markdown]
# Efetiva as operações no DB e fecha o arquivo

# %%
db.commit()
db.close()

# %% [markdown]
# ## Checa os dados no DB

# %%
dbfile = 'VivaReal.db'
tabela = 'venda'

db = sqlite3.connect(dbfile)

imoveisCaros = pd.read_sql_query(f'select * from "{tabela}" where preco>600000', db)

imoveisCaros
# Out:
#              id  ...                                               desc
# 0    2476402673  ...  101   m²     3   Quartos     3   Banheiros    ...
# 1    2473758281  ...  107   m²     3   Quartos     2   Banheiros    ...
# 2    2477112488  ...  290   m²     6   Quartos     5   Banheiros    ...
# 3    2473759712  ...  160   m²     3   Quartos     3   Banheiros    ...
# 4    2476277377  ...  84   m²     1   Quarto     2   Banheiros     1...
# ..          ...  ...                                                ...
# 275  2494214252  ...  77   m²     3   Quartos     3   Banheiros     ...
# 276  2494336886  ...  341   m²     4   Quartos     6   Banheiros    ...
# 277  2499833175  ...  162   m²     3   Quartos     4   Banheiros    ...
# 278  2498679480  ...  83   m²     2   Quartos     3   Banheiros     ...
# 279  2496574477  ...  120   m²     3   Quartos     4   Banheiros    ...
#
# [280 rows x 6 columns]

# %% [markdown]
# ## Sincronização Diária
#
# Para manter os dados em dia, este procedimento deve ser executado diariamente.
#
# No final da extração comparo todos os imóveis da minha base histórica com todos os imóveis que acabei de extrair novamente. ID por ID. É por isso que é tão importante se prender aos IDs. É neste momento que detecto qual imóvel sumiu da base, qual apareceu, qual mudou de preço ou descrição.
#
# * Imóveis que estão na minha base histórica mas não estão na última extração serão marcados como deletados ou “unlisted”.
# * Imóveis que não estavam na minha base histórica e que acabaram de aparecer na última extração serão marcados como novos.
# * Imóveis que aprentam preços diferentes entre a base histórica e a última extração devem ter essa alteração registrada em outra tabela. É interessante manter esse histórico de alteração de preços de imóveis.
#
# Certamente nossa modelagem simples de tabela não suporta registrar a mudança de preços. **Fica de lição** de casa criar uma tabela separada de preços de imóveis para que se possa manter um histórico.

# %% [markdown]
# ## Exercício
#
# Melhorar o código e extrair também a lista de amenidades (elevador, piscina, churrasqueira etc)
